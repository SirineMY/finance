# %%
#import the library sqlite3
#YOUR CODE 
import pandas as pd
import sqlite3 as sq
import mysql.connector

# %%
#create a new database and open a database connection with the name example
#YOUR CODE
try:
    conn = sq.connect("my_base.db")

    # create a data cursor cur in order execute SQL statements and fetch results from SQL queries
    #YOUR CODE 
    cur = conn.cursor()
    print("Connexion réussie à SQLite")
    # Create table with the column date, side, symbol, qty, price
    #YOUR CODE 
    cur.execute("CREATE TABLE my_table (date date, side varchar(50), symbol varchar(50), qty int, price integer)")
    conn.commit()
    print("Table SQLite est créée")
    # Insert 3 row of data: the stock APPLE ( AAPL) with the date of transaction, the nature of side ( BUY or SELL),
    #the quantity of the stock traded and the price
    #YOUR CODE 
    cur.execute("""INSERT INTO my_table(date, side, symbol, qty, price) VALUES( "2021-01-01", "BUY", "AAPL", 100, 148.48)""")
    cur.execute("""INSERT INTO my_table(date, side, symbol, qty, price) VALUES( "2021-01-02", "SELL", "AAPL", 100, 149.11)""")
    cur.execute("""INSERT INTO my_table(date, side, symbol, qty, price) VALUES( "2021-01-03", "BUY", "AAPL", 75, 144.27)""")
    cur.execute("""INSERT INTO my_table(date, side, symbol, qty, price) VALUES( "2021-01-04", "SELL", "AAPL", 75, 146.39)""")

    # Save (commit) the changes
    #YOUR CODE 
    conn.commit()
    #return all resulting rows
    #YOUR CODE 
    cur.execute("SELECT * FROM my_table")
    itemes = cur.fetchall()
    for item in itemes:
        print(item)
    # Close the connection
    #YOUR CODE 
    conn.close()
    print("Connexion SQLite est fermée")
except sq.Error as error:
    print("Erreur lors de la création du table SQLite", error)
# Out:
# Connexion réussie à SQLite
# Erreur lors de la création du table SQLite table my_table already exists

# %% [markdown]
# ## the construction of a financial database

# %% [markdown]
# Let’s start simple and only consider the structure for the equity data that we are gathering for now – in our case the constituents of the S&P500 index. We can tag on the various tables and possibly whole databases to the mix as and when we need to, i.e. when we start to deal with the spot currency data and fund data that we plan to include.
#
# the  plan is to segregate theequity data into 4 separate tables, using unique ids and foreign keys to create the relevant relationships and links between them.
#
# The tables will be as follows:

# %% [markdown]
# <img src='C:/Users/User/Desktop/Formations_Data-LAPTOP-JP680GIQ/Formations_Data-LAPTOP-JP680GIQ/Organisme_formation/Ib_cegos/AXA/MCD.png'>

# %% [markdown]
# <img src='C:\Users\User\Desktop\Formations_Data-LAPTOP-JP680GIQ\Formations_Data-LAPTOP-JP680GIQ\Organisme_formation\Ib_cegos\AXA\MCD.png'>

# %%
#import the library os and the module Error of the library sqlite3
import os
import sqlite3
import sqlite3 as sq
from sqlite3 import Error
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    #YOUR CODE 
    conn = None
    conn = sq.connect(db_file)
    return conn


def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    #YOUR CODE 
    cur = conn.cursor()
    cur.execute(create_table_sql).fetchall()
    conn.commit()
    conn.close()
    return

#the name of the database
db_name = "data.db"
        
def main():
    
    database = db_name

    
    # create the tables according to the MCD
    sql_create_exchange_table = '''CREATE TABLE exchange (
                    id INTEGER PRIMARY KEY AUTOINCREMENT, 
                    name varchar(50), 
                    currency varchar(50), 
                    code int)'''
    
    sql_create_company_table = '''CREATE TABLE company (
                    id INTEGER primary key autoincrement, 
                    name varchar(50), 
                    industry varchar(50), 
                    sector varchar(50), 
                    hq_location varchar(50), 
                    security_id integer,
                    FOREIGN KEY(security_id) REFERENCES security(id))'''
    
    
    sql_create_security_table = '''CREATE TABLE security (
                    id INTEGER primary key autoincrement, 
                    ticker varchar(50), 
                    name varchar(50), 
                    company_id integer, 
                    exchange_id integer,
                    FOREIGN KEY(company_id) REFERENCES company(id)
                    FOREIGN KEY(exchange_id) REFERENCES exchange(id))'''
    
    sql_create_security_price_table = '''CREATE TABLE security_price(
                    id INTEGER primary key autoincrement, 
                    date date, 
                    open integer, 
                    high integer, 
                    low integer, 
                    close integer, 
                    volume integer, 
                    adj_close integer, 
                    security_id integer,
                    FOREIGN KEY(security_id) REFERENCES security(id))'''

    
    # create a database connection
    #YOUR CODE
    conn = create_connection(db_name)
    # create tables
    if conn is not None:
        # create exchange table
        #YOUR CODE
        try:
            create_table(conn, sql_create_exchange_table)
        except sqlite3.Error as error:
            print("Erreur lors de la création du table SQLite", error)
            # create company table
            #YOUR CODE
        try:
            create_table(conn, sql_create_company_table)
        except sqlite3.Error as error:
            print("Erreur lors de la création du table SQLite", error)
            # create security table
            #YOUR CODE
        try:
            create_table(conn, sql_create_security_table)

        except sqlite3.Error as error:
            print("Erreur lors de la création du table SQLite", error)
            # create security_price table
            #YOUR CODE
        try:
            create_table(conn, sql_create_security_price_table)
        except sqlite3.Error as error:
            print("Erreur lors de la création du table SQLite", error)
        
    else:
        print("Error! cannot create the database connection.")
main()
# Out:
# Erreur lors de la création du table SQLite table exchange already exists
# Erreur lors de la création du table SQLite table company already exists
# Erreur lors de la création du table SQLite table security already exists
# Erreur lors de la création du table SQLite table security_price already exists

# %%
#import the library pandas , requests and io
exchange_data = pd.read_csv("https://www.iso20022.org/sites/default/files/ISO10383_MIC/ISO10383_MIC.csv", encoding='iso-8859-1' )

# %%
exchange_data.head(30)
# Out:
#      MIC OPERATING MIC OPRT/SGMT  \
# 0   DRSP          DRSP      OPRT
# 1   XCNQ          XCNQ      OPRT
# 2   PURE          XCNQ      SGMT
# 3   ZODM          ZODM      OPRT
# 4   FNFX          BGCF      SGMT
# 5   NORX          NORX      OPRT
# 6   POSE          POSE      OPRT
# 7   PUND          PUND      OPRT
# 8   UCBG          UCBG      OPRT
# 9   NZFX          XASX      SGMT
# 10  XOCH          XOCH      OPRT
# 11  BBLX          BBLX      OPRT
# 12  BACR          BAIP      SGMT
# 13  SPBE          SPBE      OPRT
# 14  OTCM          OTCM      OPRT
# 15  STUF          XSTU      SGMT
# 16  XSTP          XSTU      SGMT
# 17  STUE          XSTU      SGMT
# 18  FREX          FREX      OPRT
# 19  HCER          HMTF      SGMT
# 20  IDXM          IDXM      OPRT
# 21  MBCP          MBCP      OPRT
# 22  GMBG          MBUL      SGMT
# 23  OCEA          OCEA      OPRT
# 24  OSDS          OSDS      OPRT
# 25  OSSG          OSSG      OPRT
# 26  RR4G          RR4G      OPRT
# 27  TRUK          TRUK      OPRT
# 28  UGEN          UGEN      OPRT
# 29  XGLO          XWAR      SGMT
#
#                   MARKET NAME-INSTITUTION DESCRIPTION  \
# 0                   EURONEXT  UK - REPORTING SERVICES
# 1                        CANADIAN SECURITIES EXCHANGE
# 2                 CANADIAN SECURITIES EXCHANGE - PURE
# 3                                       ZODIA MARKETS
# 4                                       FENICS FX ECN
# 5                                     NASDAQ OSLO ASA
# 6                            PORTFOLIO STOCK EXCHANGE
# 7                                         PUNDION LLC
# 8                                UNICREDIT BULBANK AD
# 9                 ASX - NEW ZEALAND FUTURES & OPTIONS
# 10                                    ONECHICAGO, LLC
# 11                                  BONDBLOX EXCHANGE
# 12          BANK OF AMERICA SECURITIES - CENTRAL RISK
# 13                         SPB EXCHANGE - ALL MARKETS
# 14                         OTC LINK ATS - OTC MARKETS
# 15  BOERSE STUTTGART - FREIVERKEHR - TECHNICAL PLA...
# 16            BOERSE STUTTGART - TECHNICAL PLATFORM 3
# 17  BOERSE STUTTGART - REGULIERTER MARKT - TECHNIC...
# 18                               COINBASE DERIVATIVES
# 19            HI-CERT - MULTILATERAL TRADING FACILITY
# 20                                   IDX MARKETS, LLC
# 21                                     MILLENNIUM BCP
# 22                          MTF SOFIA - GROWTH MARKET
# 23              BLUE OCEAN ALTERNATIVE TRADING SYSTEM
# 24                    OSL DIGITAL SECURITIES EXCHANGE
# 25                                   OSL SG EXCHANGES
# 26                                          ROUTE4GAS
# 27                             TRADING 212 UK LIMITED
# 28                                   UNITEDBLOCKTRADE
# 29  WARSAW STOCK EXCHANGE/ EQUITIES/GLOBAL CONNECT...
#
#                              LEGAL ENTITY NAME                   LEI  \
# 0                      EURONEXT LONDON LIMITED  969500HMVSZ0TCV65D58
# 1                           CNSX MARKETS, INC.                   NaN
# 2                           CNSX MARKETS, INC.                   NaN
# 3               ZODIA MARKETS HOLDINGS LIMITED  5493006GZOHISU7JTC27
# 4                               FENICS FX, LLC  549300I0NONVB9S5DZ56
# 5                              NASDAQ OSLO ASA  5493003IZZWOHHJY1L88
# 6   EUROPEAN DIGITAL SECURITIES EXCHANGE, S.L.  959800UP9ANDBHTKJ408
# 7                                  PUNDION LLC  549300FOYST42PEQ1R51
# 8                         UNICREDIT BULBANK AD  549300Z7V2WOFIMUEK50
# 9         AUSTRALIAN SECURITIES EXCHANGE (ASX)  549300SDXT36XYPVWI79
# 10                                         NaN                   NaN
# 11                          BONDEVALUE PTE LTD                   NaN
# 12                                         NaN  GGDZP1UYGU9STUHRDP48
# 13     PUBLIC JOINT-STOCK COMPANY SPB EXCHANGE  253400T8G8SXRUHTL526
# 14                      OTC MARKETS GROUP INC.  254900LQDMW14QIVAH45
# 15                            BOERSE STUTTGART  529900A0WHA0NVXY0G45
# 16                            BOERSE STUTTGART  529900A0WHA0NVXY0G45
# 17                            BOERSE STUTTGART  529900A0WHA0NVXY0G45
# 18                               LMX LABS, LLC  549300QHD76EP6ZKTT48
# 19                           HI-MTF SIM S.P.A.  815600F681369854E440
# 20                            IDX MARKETS, LLC  9845006C2FC4E0741B90
# 21              BANCO COMERCIAL PORTUGUES S.A.  JU1U6S0DG9YLT7N8ZV32
# 22                                   CAPMAN AD  5299003795MPR9UZ1J25
# 23                         BLUE OCEAN ATS, LLC                   NaN
# 24                                         NaN  549300WBXH3AFK5BRJ77
# 25                            OSL SG PTE. LTD.  5493005YD2GDV5LCUD15
# 26                              ROUTE4GAS B.V.  724500EY0KGMVVONVS49
# 27                      TRADING 212 UK LIMITED  2138006AXBAC4F1AWD58
# 28                      UNITED GENERAL LIMITED  9845009F695B98C2BA24
# 29                       WARSAW STOCK EXCHANGE  25940039ZHD3Z37GKR71
#
#    MARKET CATEGORY CODE        ACRONYM ISO COUNTRY CODE (ISO 3166)       CITY  \
# 0                  APPA            NaN                          GB     LONDON
# 1                  RMKT     CSE LISTED                          CA    TORONTO
# 2                  NSPD       CSE-PURE                          CA    TORONTO
# 3                  NSPD            NaN                          GB     LONDON
# 4                  NSPD            NaN                          US   NEW YORK
# 5                  RMKT            NaN                          NO       OSLO
# 6                  MLTF            NaN                          ES     MADRID
# 7                  NSPD            NaN                          US   NEW YORK
# 8                  SINT            NaN                          BG      SOFIA
# 9                  NSPD            ASX                          AU     SYDNEY
# 10                 NSPD            NaN                          US    CHICAGO
# 11                 NSPD            BBX                          SG  SINGAPORE
# 12                 NSPD            NaN                          HK  HONG KONG
# 13                 NSPD            SPB                          RU     MOSCOW
# 14                 NSPD            NaN                          US   NEW YORK
# 15                 NSPD            NaN                          DE  STUTTGART
# 16                 NSPD            NaN                          DE  STUTTGART
# 17                 NSPD            NaN                          DE  STUTTGART
# 18                 DCMS            CDE                          US    CHICAGO
# 19                 MLTF            NaN                          IT     MILANO
# 20                 ATSS            NaN                          US   NEW YORK
# 21                 SINT  MILLENNIUMBCP                          PT      PORTO
# 22                 NSPD            NaN                          BG      SOFIA
# 23                 ATSS          BOATS                          US   SEA GIRT
# 24                 NSPD          OSLDS                          HK  HONG KONG
# 25                 NSPD          OSLSG                          SG  SINGAPORE
# 26                 NSPD            R4G                          NL  AMSTERDAM
# 27                 NSPD            NaN                          GB     LONDON
# 28                 NSPD            NaN                          GB   BRADFORD
# 29                 MLTF            NaN                          PL     WARSAW
#
#                                               WEBSITE   STATUS  CREATION DATE  \
# 0                                    WWW.EURONEXT.COM   ACTIVE       20210927
# 1                                      WWW.THECSE.COM   ACTIVE       20090427
# 2                                      WWW.THECSE.COM   ACTIVE       20061225
# 3                               WWW.ZODIA-MARKETS.COM   ACTIVE       20210927
# 4                                    WWW.FENICSFX.COM   ACTIVE       20210927
# 5       WWW.NASDAQ.COM/SOLUTIONS/EUROPEAN-COMMODITIES   ACTIVE       20110523
# 6                              WWW.PORTFOLIO.EXCHANGE   ACTIVE       20210927
# 7                                     WWW.PUNDION.COM   ACTIVE       20210927
# 8                             WWW.UNICREDITBULBANK.BG   ACTIVE       20210927
# 9                                      WWW.ASX.COM.AU   ACTIVE       20070924
# 10                                 WWW.ONECHICAGO.COM  EXPIRED       20050627
# 11                                   WWW.BONDBLOX.COM   ACTIVE       20210823
# 12                                     WWW.BOFAML.COM   ACTIVE       20210726
# 13                             HTTPS://SPBEXCHANGE.RU   ACTIVE       20210322
# 14                                 WWW.OTCMARKETS.COM   ACTIVE       20120528
# 15                            WWW.BOERSE-STUTTGART.DE   ACTIVE       20210726
# 16                            WWW.BOERSE-STUTTGART.DE   ACTIVE       20210726
# 17                            WWW.BOERSE-STUTTGART.DE   ACTIVE       20210726
# 18                       WWW.COINBASE.COM/DERIVATIVES   ACTIVE       20201026
# 19                                      WWW.HIMTF.COM   ACTIVE       20200727
# 20                                 WWW.IDXMARKETS.COM   ACTIVE       20210628
# 21  HTTPS://IND.MILLENNIUMBCP.PT/PT/PARTICULARES/P...   ACTIVE       20210628
# 22                                      WWW.CAPMAN.BG   ACTIVE       20210628
# 23                               WWW.BLUEOCEANATS.COM   ACTIVE       20210628
# 24                            HTTPS://OSL.COM/EN/HOME   ACTIVE       20210628
# 25                                     WWW.SG.OSL.COM   ACTIVE       20210628
# 26                        HTTPS://ROUTE4GAS.COM/INFO/   ACTIVE       20210628
# 27                                 WWW.TRADING212.COM   ACTIVE       20210628
# 28                            WWW.UNITEDGENERAL.CO.UK   ACTIVE       20210628
# 29                                         WWW.GPW.PL   ACTIVE       20210426
#
#     LAST UPDATE DATE  LAST VALIDATION DATE  EXPIRY DATE  \
# 0           20210927            20210927.0          NaN
# 1           20210927            20210927.0          NaN
# 2           20210927            20210927.0          NaN
# 3           20210927            20210927.0          NaN
# 4           20210927            20210927.0          NaN
# 5           20210927            20210927.0          NaN
# 6           20210927                   NaN          NaN
# 7           20210927            20210927.0          NaN
# 8           20210927            20210927.0          NaN
# 9           20210927            20210927.0          NaN
# 10          20210823            20210823.0   20210823.0
# 11          20210823            20210823.0          NaN
# 12          20210726                   NaN          NaN
# 13          20210726            20210726.0          NaN
# 14          20210726            20210726.0          NaN
# 15          20210726                   NaN          NaN
# 16          20210726                   NaN          NaN
# 17          20210726                   NaN          NaN
# 18          20220822            20220822.0          NaN
# 19          20210628            20210628.0          NaN
# 20          20210628                   NaN          NaN
# 21          20210628                   NaN          NaN
# 22          20210628                   NaN          NaN
# 23          20210628                   NaN          NaN
# 24          20210628                   NaN          NaN
# 25          20210628                   NaN          NaN
# 26          20210628                   NaN          NaN
# 27          20210628                   NaN          NaN
# 28          20210628                   NaN          NaN
# 29          20210628            20210628.0          NaN
#
#                                              COMMENTS
# 0                   APPROVED PUBLICATION ARRANGEMENT.
# 1   FORMERLY KNOWN AS PURE (CSE OTHER LISTED) FORM...
# 2   FORMERLY KNOWN AS PURE (CSE OTHER LISTED) FORM...
# 3                 CRYPTOASSET BROKERAGE AND EXCHANGE.
# 4                  ELECTRONIC COMMUNICATIONS NETWORK.
# 5                                                 NaN
# 6                      MULTILATERAL TRADING FACILITY.
# 7                                    EQUITY PRODUCTS.
# 8                            SYSTEMATIC INTERNALISER.
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  SHARES, DEPOSITARY RECEIPTS, GOVERNMENT BONDS,...
# 14                   OPERATIONAL MIC FOR OTC MARKETS.
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19          MTF FOR CERTIFICATES AND COVERED WARRANT.
# 20  REGISTERED ALTERNATIVE TRADING SYSTEM (ATS) FO...
# 21  SYSTEMATIC INTERNALISER IN FX DERIVATIVES AND ...
# 22                                                NaN
# 23  BLUE OCEAN ATS, LLC IS A US REGISTERED BROKER ...
# 24  OSL DIGITAL SECURITIES - ASIA'S LEADING DIGITA...
# 25  ASIA LEADING DIGITAL ASSET PLATFORM - OSL SG E...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                     MULTILATERAL TRADING FACILITY.

# %%
exchange_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2561 entries, 0 to 2560
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   MIC                                  2561 non-null   object
#  1   OPERATING MIC                        2561 non-null   object
#  2   OPRT/SGMT                            2561 non-null   object
#  3   MARKET NAME-INSTITUTION DESCRIPTION  2561 non-null   object
#  4   LEGAL ENTITY NAME                    495 non-null    object
#  5   LEI                                  1833 non-null   object
#  6   MARKET CATEGORY CODE                 2559 non-null   object
#  7   ACRONYM                              890 non-null    object
#  8   ISO COUNTRY CODE (ISO 3166)          2560 non-null   object
#  9   CITY                                 2559 non-null   object
#  10  WEBSITE                              2387 non-null   object
#  11  STATUS                               2561 non-null   object
#  12  CREATION DATE                        2561 non-null   int64
#  13  LAST UPDATE DATE                     2561 non-null   int64
#  14  LAST VALIDATION DATE                 213 non-null    float64
#  15  EXPIRY DATE                          438 non-null    float64
#  16  COMMENTS                             1502 non-null   object
# dtypes: float64(2), int64(2), object(13)
# memory usage: 340.3+ KB

# %%
exchange_data = exchange_data[['ISO COUNTRY CODE (ISO 3166)', 'MIC', 'MARKET NAME-INSTITUTION DESCRIPTION', 'ACRONYM']]
exchange_data.head()
# Out:
#   ISO COUNTRY CODE (ISO 3166)   MIC  MARKET NAME-INSTITUTION DESCRIPTION  \
# 0                          GB  DRSP    EURONEXT  UK - REPORTING SERVICES
# 1                          CA  XCNQ         CANADIAN SECURITIES EXCHANGE
# 2                          CA  PURE  CANADIAN SECURITIES EXCHANGE - PURE
# 3                          GB  ZODM                        ZODIA MARKETS
# 4                          US  FNFX                        FENICS FX ECN
#
#       ACRONYM
# 0         NaN
# 1  CSE LISTED
# 2    CSE-PURE
# 3         NaN
# 4         NaN

# %%
exchange_data.rename(columns={'ISO COUNTRY CODE (ISO 3166)' : 'country_code', 
                              'MIC':'code', 
                              'MARKET NAME-INSTITUTION DESCRIPTION': 'name',
                              'ACRONYM':'acronym'}, inplace=True)
exchange_data.head()
# Out:
#   country_code  code                                 name     acronym
# 0           GB  DRSP    EURONEXT  UK - REPORTING SERVICES         NaN
# 1           CA  XCNQ         CANADIAN SECURITIES EXCHANGE  CSE LISTED
# 2           CA  PURE  CANADIAN SECURITIES EXCHANGE - PURE    CSE-PURE
# 3           GB  ZODM                        ZODIA MARKETS         NaN
# 4           US  FNFX                        FENICS FX ECN         NaN

# %%
exchange_data['id'] = exchange_data.index
exchange_data.head()
# Out:
#   country_code  code                                 name     acronym  id
# 0           GB  DRSP    EURONEXT  UK - REPORTING SERVICES         NaN   0
# 1           CA  XCNQ         CANADIAN SECURITIES EXCHANGE  CSE LISTED   1
# 2           CA  PURE  CANADIAN SECURITIES EXCHANGE - PURE    CSE-PURE   2
# 3           GB  ZODM                        ZODIA MARKETS         NaN   3
# 4           US  FNFX                        FENICS FX ECN         NaN   4

# %%
import numpy as np
x=exchange_data.groupby(['country_code']).sum()
conditionlist = [
    (exchange_data['country_code']== 'US'),
    (exchange_data['country_code']== 'GB'),
    (exchange_data['country_code']== 'DE')]
choicelist = ['USD', 'GBP', 'EUR']
exchange_data['currency'] = np.select(conditionlist, choicelist, default='Not Specified')
exchange_data[['id', 'name', 'currency', 'code']].head(30)
# create the column currency in the the dataframe exchange_data whose values 
#are mapped with the country code : US => USD, GB =>GBP, DE =>EUR
# Out:
#     id                                               name       currency  code
# 0    0                  EURONEXT  UK - REPORTING SERVICES            GBP  DRSP
# 1    1                       CANADIAN SECURITIES EXCHANGE  Not Specified  XCNQ
# 2    2                CANADIAN SECURITIES EXCHANGE - PURE  Not Specified  PURE
# 3    3                                      ZODIA MARKETS            GBP  ZODM
# 4    4                                      FENICS FX ECN            USD  FNFX
# 5    5                                    NASDAQ OSLO ASA  Not Specified  NORX
# 6    6                           PORTFOLIO STOCK EXCHANGE  Not Specified  POSE
# 7    7                                        PUNDION LLC            USD  PUND
# 8    8                               UNICREDIT BULBANK AD  Not Specified  UCBG
# 9    9                ASX - NEW ZEALAND FUTURES & OPTIONS  Not Specified  NZFX
# 10  10                                    ONECHICAGO, LLC            USD  XOCH
# 11  11                                  BONDBLOX EXCHANGE  Not Specified  BBLX
# 12  12          BANK OF AMERICA SECURITIES - CENTRAL RISK  Not Specified  BACR
# 13  13                         SPB EXCHANGE - ALL MARKETS  Not Specified  SPBE
# 14  14                         OTC LINK ATS - OTC MARKETS            USD  OTCM
# 15  15  BOERSE STUTTGART - FREIVERKEHR - TECHNICAL PLA...            EUR  STUF
# 16  16            BOERSE STUTTGART - TECHNICAL PLATFORM 3            EUR  XSTP
# 17  17  BOERSE STUTTGART - REGULIERTER MARKT - TECHNIC...            EUR  STUE
# 18  18                               COINBASE DERIVATIVES            USD  FREX
# 19  19            HI-CERT - MULTILATERAL TRADING FACILITY  Not Specified  HCER
# 20  20                                   IDX MARKETS, LLC            USD  IDXM
# 21  21                                     MILLENNIUM BCP  Not Specified  MBCP
# 22  22                          MTF SOFIA - GROWTH MARKET  Not Specified  GMBG
# 23  23              BLUE OCEAN ALTERNATIVE TRADING SYSTEM            USD  OCEA
# 24  24                    OSL DIGITAL SECURITIES EXCHANGE  Not Specified  OSDS
# 25  25                                   OSL SG EXCHANGES  Not Specified  OSSG
# 26  26                                          ROUTE4GAS  Not Specified  RR4G
# 27  27                             TRADING 212 UK LIMITED            GBP  TRUK
# 28  28                                   UNITEDBLOCKTRADE            GBP  UGEN
# 29  29  WARSAW STOCK EXCHANGE/ EQUITIES/GLOBAL CONNECT...  Not Specified  XGLO

# %%
# save the data in a sql table exchange in the data db_name
#YOUR CODE
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)
exchange_data.to_sql('exchange', con=engine, if_exists='append', index = False)
engine.execute("SELECT * FROM exchange").fetchall()
# Out:
# [('GB', 'DRSP', 'EURONEXT  UK - REPORTING SERVICES', None, 0, 'GBP'),
#  ('CA', 'XCNQ', 'CANADIAN SECURITIES EXCHANGE', 'CSE LISTED', 1, 'Not Specified'),
#  ('CA', 'PURE', 'CANADIAN SECURITIES EXCHANGE - PURE', 'CSE-PURE', 2, 'Not Specified'),
#  ('GB', 'ZODM', 'ZODIA MARKETS', None, 3, 'GBP'),
#  ('US', 'FNFX', 'FENICS FX ECN', None, 4, 'USD'),
#  ('NO', 'NORX', 'NASDAQ OSLO ASA', None, 5, 'Not Specified'),
#  ('ES', 'POSE', 'PORTFOLIO STOCK EXCHANGE', None, 6, 'Not Specified'),
#  ('US', 'PUND', 'PUNDION LLC', None, 7, 'USD'),
#  ('BG', 'UCBG', 'UNICREDIT BULBANK AD', None, 8, 'Not Specified'),
#  ('AU', 'NZFX', 'ASX - NEW ZEALAND FUTURES & OPTIONS', 'ASX', 9, 'Not Specified'),
#  ('US', 'XOCH', 'ONECHICAGO, LLC', None, 10, 'USD'),
#  ('SG', 'BBLX', 'BONDBLOX EXCHANGE', 'BBX', 11, 'Not Specified'),
#  ('HK', 'BACR', 'BANK OF AMERICA SECURITIES - CENTRAL RISK', None, 12, 'Not Specified'),
#  ('RU', 'SPBE', 'SPB EXCHANGE - ALL MARKETS', 'SPB', 13, 'Not Specified'),
#  ('US', 'OTCM', 'OTC LINK ATS - OTC MARKETS', None, 14, 'USD'),
#  ('DE', 'STUF', 'BOERSE STUTTGART - FREIVERKEHR - TECHNICAL PLATFORM 3', None, 15, 'EUR'),
#  ('DE', 'XSTP', 'BOERSE STUTTGART - TECHNICAL PLATFORM 3', None, 16, 'EUR'),
#  ('DE', 'STUE', 'BOERSE STUTTGART - REGULIERTER MARKT - TECHNICAL PLATFORM 3', None, 17, 'EUR'),
#  ('US', 'FREX', 'COINBASE DERIVATIVES', 'CDE', 18, 'USD'),
#  ('IT', 'HCER', 'HI-CERT - MULTILATERAL TRADING FACILITY', None, 19, 'Not Specified'),
#  ('US', 'IDXM', 'IDX MARKETS, LLC', None, 20, 'USD'),
#  ('PT', 'MBCP', 'MILLENNIUM BCP', 'MILLENNIUMBCP', 21, 'Not Specified'),
#  ('BG', 'GMBG', 'MTF SOFIA - GROWTH MARKET', None, 22, 'Not Specified'),
#  ('US', 'OCEA', 'BLUE OCEAN ALTERNATIVE TRADING SYSTEM', 'BOATS', 23, 'USD'),
#  ('HK', 'OSDS', 'OSL DIGITAL SECURITIES EXCHANGE', 'OSLDS', 24, 'Not Specified'),
#  ('SG', 'OSSG', 'OSL SG EXCHANGES', 'OSLSG', 25, 'Not Specified'),
#  ('NL', 'RR4G', 'ROUTE4GAS', 'R4G', 26, 'Not Specified'),
#  ('GB', 'TRUK', 'TRADING 212 UK LIMITED', None, 27, 'GBP'),
#  ('GB', 'UGEN', 'UNITEDBLOCKTRADE', None, 28, 'GBP'),
#  ('PL', 'XGLO', 'WARSAW STOCK EXCHANGE/ EQUITIES/GLOBAL CONNECT - MTF', None, 29, 'Not Specified'),
#  ('PL', 'WIND', 'WARSAW STOCK EXCHANGE/INDICES', 'GPWB', 30, 'Not Specified'),
#  ('SG', 'CNOD', 'CNODE', 'CNODE', 31, 'Not Specified'),
#  ('LU', 'BGLU', 'BGL BNP PARIBAS', 'BGL', 32, 'Not Specified'),
#  ('US', 'FNIX', 'GFI SECURITIES LLC - FENICS DELTA X', None, 33, 'USD'),
#  ('US', 'LATG', 'GFI SECURITIES LLC - CREDITMATCH (LATG)', 'LATG', 34, 'USD'),
#  ('US', 'GFAM', 'GFI SECURITIES LLC - ALL MARKETS', None, 35, 'USD'),
#  ('CY', 'TMCY', 'TRADING 212 MARKETS LIMITED', 'T212CY', 36, 'Not Specified'),
#  ('US', 'UBEC', 'UNIVERSAL BARTER EXCHANGE CREDIT UNION', 'UBECU', 37, 'USD'),
#  ('FR', 'ENSL', 'ENGNSOL - OMP', None, 38, 'Not Specified'),
#  ('FR', 'ESLO', 'ENGNSOL', None, 39, 'Not Specified'),
#  ('GB', 'IOTF', 'ICAP UK OTF', 'ISL OTF', 40, 'GBP'),
#  ('DE', 'SEBA', 'STIFEL EUROPE BANK AG', 'SEBA', 41, 'EUR'),
#  ('IT', 'UBIM', 'UBI BANCA', 'UBI', 42, 'Not Specified'),
#  ('GB', 'XUBS', 'AQUIS EXCHANGE PLC - AMP - DARK ORDER BOOK', None, 43, 'GBP'),
#  ('GB', 'XUMP', 'UBS MTF LIMITED - PERIODIC AUCTION ORDER BOOK', None, 44, 'GBP'),
#  ('US', 'AMLG', 'AMERICAN LEDGER ATS', None, 45, 'USD'),
#  ('FR', 'BRED', 'BRED BANQUE POPULAIRE', None, 46, 'Not Specified'),
#  ('DE', 'DBMO', 'DEUTSCHE BANK - MANUAL OTC', 'MANUAL OTC', 47, 'EUR'),
#  ('DE', 'DBLN', 'DEUTSCHE BANK AG - LONDON', None, 48, 'EUR'),
#  ('GB', 'DBIX', 'DEUTSCHE BANK AG - LONDON', None, 49, 'GBP'),
#  ('RU', 'RUSX', 'NON-PROFIT PARTNERSHIP FOR THE DEVELOPMENT OF FINANCIAL MARKET RTS', 'NP RTS', 50, 'Not Specified'),
#  ('GB', 'UNGB', 'UNICREDIT BANK AG - LONDON BRANCH - UK', None, 51, 'GBP'),
#  ('AU', 'XLQC', 'LIQUIDITY CUBE PTY LTD', None, 52, 'Not Specified'),
#  ('RU', 'XMOS', 'CENTRAL COUNTERPARTY CLEARING CENTER MFB - JOINT-STOCK COMPANY', 'MFB', 53, 'Not Specified'),
#  ('AE', 'ABXX', 'VENOMEX LIMITED (EX. YOSHI MARKETS)', 'VMX', 54, 'Not Specified'),
#  ('GB', 'CFIC', 'CHINAFICC', None, 55, 'GBP'),
#  ('FR', 'HBFR', 'HSBC CONTINENTAL EUROPE', None, 56, 'Not Specified'),
#  ('US', 'KLSH', 'KALSHIEX LLC', 'KEX', 57, 'USD'),
#  ('JP', 'MUDX', 'MITSUBISHI DIAMOND CROSSING', 'MDX', 58, 'Not Specified'),
#  ('GB', 'TRAX', 'MARKETAXESS POST-TRADE LIMITED - APA', None, 59, 'GBP'),
#  ('NL', 'TRNL', 'MARKETAXESS POST-TRADE B.V. - APA', None, 60, 'Not Specified'),
#  ('RU', 'XPET', 'STOCK EXCHANGE SAINT PETERSBURG', 'SPBEX', 61, 'Not Specified'),
#  ('US', 'LEVL', 'LEVEL ATS', 'LEVEL', 62, 'USD'),
#  ('US', 'EBXV', 'LEVEL ATS - VWAP CROSS', 'LEVEL', 63, 'USD'),
#  ('IE', 'FXRS', 'FINANCIAL AND RISK TRANSACTIONS SERVICES IRELAND LIMITED - FXALL RFS MTF', 'FRTSIL', 64, 'Not Specified'),
#  ('US', 'FXPS', 'REFINITIV SEF REQUEST FOR STREAM', 'RSEF (RFS)', 65, 'USD'),
#  ('BB', 'XBIS', 'BARBADOS STOCK EXCHANGE - INTERNATIONAL SECURITIES MARKET', 'ISM', 66, 'Not Specified'),
#  ('US', 'STRM', 'PURESTREAM', None, 67, 'USD'),
#  ('NL', 'ABNC', 'ABN AMRO CLEARING BANK', 'AACB SI', 68, 'Not Specified'),
#  ('US', 'BNPC', 'BNPP CORTEX ATS', 'BNPX', 69, 'USD'),
#  ('GR', 'PBGR', 'PIRAEUS BANK', None, 70, 'Not Specified'),
#  ('IE', 'SIDX', 'SCOTIABANK (IRELAND) DESIGNATED ACTIVITY COMPANY', 'SIDAC', 71, 'Not Specified'),
#  ('GB', 'SIFX', 'SIEGE FX LIMITED', None, 72, 'GBP'),
#  ('ES', 'TEUR', 'TRADITION ESPANA OTF', None, 73, 'Not Specified'),
#  ('FR', 'TPEE', 'TP ICAP EU - MTF - EQUITY AND ETF', None, 74, 'Not Specified'),
#  ('IE', 'AILT', 'ARRACO IRELAND LTD', None, 75, 'Not Specified'),
#  ('GB', 'ARAX', 'ARRACO GLOBAL MARKETS LTD', None, 76, 'GBP'),
#  ('US', 'CGXS', 'ONECHRONOS', None, 77, 'USD'),
#  ('SG', 'EQOC', 'EQUOS SPOT', None, 78, 'Not Specified'),
#  ('SG', 'EQOD', 'EQUOS DERIVATIVES', None, 79, 'Not Specified'),
#  ('FR', 'AQED', 'AQUIS EXCHANGE EUROPE NON DISPLAY ORDER BOOK (NDOB)', None, 80, 'Not Specified'),
#  ('GB', 'EIXE', 'AQUIS EXCHANGE PLC AQUIS - EIX INFRASTRUCTURE BOND MARKET', 'AQUIS-EIX', 81, 'GBP'),
#  ('FR', 'HPCS', 'HPC ENERGY TRADING', 'HPC', 82, 'Not Specified'),
#  ('AE', 'MIDC', 'MIDCHAINS', None, 83, 'Not Specified'),
#  ('GB', 'RABL', 'RABOBANK INTERNATIONAL UK', None, 84, 'GBP'),
#  ('ZA', 'RMMS', 'RMB MORGAN STANLEY', None, 85, 'Not Specified'),
#  ('ZA', 'RMMX', 'RMB MORGAN STANLEY - INVENTORY MANAGER', None, 86, 'Not Specified'),
#  ('SE', 'NOCO', 'NASDAQ STOCKHOLM AB - COMMODITIES', None, 87, 'Not Specified'),
#  ('ES', 'MABX', 'BME MTF EQUITY (IIC AND ECR SEGMENTS)', 'MAB', 88, 'Not Specified'),
#  ('ES', 'CECA', 'CECABANK', None, 89, 'Not Specified'),
#  ('GB', 'DBDC', 'DEUTSCHE BANK - DIRECT CAPITAL ACCESS', 'DCA', 90, 'GBP'),
#  ('GB', 'DBSE', 'DEUTSCHE BANK - SUPERX EU', 'SUPERX EU', 91, 'GBP'),
#  ('GB', 'DBCX', 'DEUTSCHE BANK - CLOSE CROSS', 'CLX', 92, 'GBP'),
#  ('GB', 'DBCR', 'DEUTSCHE BANK - CENTRAL RISK BOOK', 'CENTRAL RISK BOOK', 93, 'GBP'),
#  ('FR', 'HPCO', 'HPC ETRADING', 'HPC', 94, 'Not Specified'),
#  ('FR', 'ICOR', 'ICAP EU -  OTF - REGISTRATION', 'TPIE', 95, 'Not Specified'),
#  ('NL', 'JNSI', 'JANE STREET NETHERLANDS B.V.', None, 96, 'Not Specified'),
#  ('FR', 'TPER', 'TULLETT PREBON EU OTF - REGISTRATION', 'TPIE', 97, 'Not Specified'),
#  ('CH', 'XSDX', 'SIX DIGITAL EXCHANGE', 'SIX', 98, 'Not Specified'),
#  ('CH', 'XSWX', 'SIX SWISS EXCHANGE', 'SIX', 99, 'Not Specified'),
#  ('CH', 'XDLP', 'SIX SWISS EXCHANGE - DEAL POOL - BOOK BUILDING AND ANNOUNCEMENT PLATFORM', 'SIX', 100, 'Not Specified'),
#  ('CH', 'XSWM', 'SIX SWISS EXCHANGE - SIX SWISS EXCHANGE AT MIDPOINT', 'SIX', 101, 'Not Specified'),
#  ('CH', 'XSLS', 'SIX SWISS EXCHANGE - SLS', 'SIX', 102, 'Not Specified'),
#  ('CH', 'XSEB', 'SIX SWISS EXCHANGE - EBBO BOOK', 'SIX', 103, 'Not Specified'),
#  ('CH', 'XBTR', 'SIX SWISS BILATERAL TRADING PLATFORM FOR STRUCTURED OTC PRODUCTS', 'SIX', 104, 'Not Specified'),
#  ('CH', 'XVTX', 'SIX SWISS EXCHANGE - BLUE CHIPS SEGMENT', 'SIX', 105, 'Not Specified'),
#  ('CH', 'XQOD', 'SIX SWISS EXCHANGE - ETF QOD', 'SIX', 106, 'Not Specified'),
#  ('CH', 'XQMH', 'SIX SWISS EXCHANGE - STRUCTURED PRODUCTS', 'SIX', 107, 'Not Specified'),
#  ('JP', 'BNPX', 'BNP PARIBAS ALTERNATIVE TRADING SYSTEM', None, 108, 'Not Specified'),
#  ('RO', 'BTRL', 'BANCA TRANSILVANIA S.A.', None, 109, 'Not Specified'),
#  ('GB', 'NTUK', 'NATIXIS LONDON BRANCH', 'NLB', 110, 'GBP'),
#  ('SG', 'EQOS', 'EQUOS', None, 111, 'Not Specified'),
#  ('EE', 'LMNR', 'LUMINOR BANK AS', None, 112, 'Not Specified'),
#  ('NL', 'CEDX', 'CBOE EUROPE DERIVATIVES', 'CBOE NL CEDX', 113, 'Not Specified'),
#  ('CA', 'EQCA', 'EQUILEND CANADA CORP.', None, 114, 'Not Specified'),
#  ('US', 'EQUS', 'EQUILEND LLC', None, 115, 'USD'),
#  ('GB', 'EVOL', 'EVOLUTION MARKETS', 'EVOL', 116, 'GBP'),
#  ('NO', 'STEE', 'NASDAQ COMMODITIES - STEEL COMMODITY', None, 117, 'Not Specified'),
#  ('NO', 'BULK', 'NASDAQ COMMODITIES - BULK COMMODITY', None, 118, 'Not Specified'),
#  ('FR', 'RBCC', 'RBC - PARIS BRANCH', None, 119, 'Not Specified'),
#  ('BG', 'BEBG', 'BULGARIAN ENERGY TRADING PLATFORM', 'BETP', 120, 'Not Specified'),
#  ('DE', 'CBKS', 'COMMERZBANK INTEREST RATE SWAPS', None, 121, 'EUR'),
#  ('US', 'XTXD', 'XTX DIRECT', None, 122, 'USD'),
#  ('DE', 'SSWM', 'SSW MARKET MAKING', 'SSWMM', 123, 'EUR'),
#  ('NO', 'XOAS', 'EURONEXT EXPAND OSLO', None, 124, 'Not Specified'),
#  ('NO', 'XOSL', 'OSLO BORS', None, 125, 'Not Specified'),
#  ('US', 'SGA2', 'SG AMERICAS SECURITIES, LLC - SECOND VENUE', 'SGAS', 126, 'USD'),
#  ('TR', 'EWRM', 'TURKISH MERCANTILE EXCHANGE - ELECTRONIC WAREHOUSE RECEIPT MARKET', None, 127, 'Not Specified'),
#  ('NO', 'MERK', 'EURONEXT GROWTH - OSLO', None, 128, 'Not Specified'),
#  ('NO', 'XOBD', 'OSLO BORS - DERIVATIVES MARKET', None, 129, 'Not Specified'),
#  ('ES', 'BSAB', 'BANCO DE SABADELL, S.A.', 'BSAB', 130, 'Not Specified'),
#  ('GB', 'BSPL', 'BNP PARIBAS SECURITIES SERVICES LONDON BRANCH', 'BP2S LB SI', 131, 'GBP'),
#  ('US', 'BSTX', 'BOSTON SECURITY TOKEN EXCHANGE LLC', None, 132, 'USD'),
#  ('LI', 'XNOM', 'NOMISMA (LIECHTENSTEIN) AG', None, 133, 'Not Specified'),
#  ('US', 'BBOK', 'BARCLAYS SINGLE DEALER PLATFORM', 'BBOK', 134, 'USD'),
#  ('DE', 'BLFX', 'BAYERNLB - FX DERIVATIVES MARKET', None, 135, 'EUR'),
#  ('DE', 'OLBB', 'OLDENBURGISCHE LANDESBANK AG FX  HANDEL', None, 136, 'EUR'),
#  ('FR', 'SGMU', 'SIGMA X EUROPE NON-DISPLAYED BOOK', 'GSPIC', 137, 'Not Specified'),
#  ('MU', 'AFEX', 'AFRINEX LIMITED', None, 138, 'Not Specified'),
#  ('GB', 'BNPL', 'BNP PARIBAS SA LONDON BRANCH', 'BNPP SA LB SI', 139, 'GBP'),
#  ('PL', 'CAPL', 'CREDIT AGRICOLE BANK POLSKA S.A.', None, 140, 'Not Specified'),
#  ('US', 'CCMX', 'CARTAX', None, 141, 'USD'),
#  ('US', 'ONEC', 'CITI-ONE', None, 142, 'USD'),
#  ('GB', 'MBSI', 'MORGAN STANLEY BANK INTERNATIONAL LIMITED - SYSTEMATIC INTERNALISER', None, 143, 'GBP'),
#  ('GB', 'MSBI', 'MORGAN STANLEY BANK INTERNATIONAL LIMITED', None, 144, 'GBP'),
#  ('FR', 'SGMV', 'SIGMA X EUROPE AUCTION BOOK', None, 145, 'Not Specified'),
#  ('FR', 'SGMW', 'SIGMA X EUROPE NEGOTIATED TRADE', None, 146, 'Not Specified'),
#  ('BG', 'T212', 'TRADING 212 LIMITED', None, 147, 'Not Specified'),
#  ('TR', 'TMEX', 'TURKISH MERCANTILE EXCHANGE', None, 148, 'Not Specified'),
#  ('US', 'XCBO', 'CBOE GLOBAL MARKETS INC.', 'CBOE', 149, 'USD'),
#  ('US', 'CONE', 'CBOE OPTIONS EXCHANGE', None, 150, 'USD'),
#  ('US', 'CTWO', 'CBOE C2 OPTIONS EXCHANGE', None, 151, 'USD'),
#  ('US', 'C2OX', 'CBOE C2 OPTIONS EXCHANGE', 'C2OX', 152, 'USD'),
#  ('SE', 'PEPQ', 'PEPINS - MTF - QUARTER', None, 153, 'Not Specified'),
#  ('SE', 'PEPY', 'PEPINS - MTF - YEAR', None, 154, 'Not Specified'),
#  ('SE', 'PEPH', 'PEPINS - MTF - HALF-YEAR', None, 155, 'Not Specified'),
#  ('SE', 'PEPM', 'PEPINS - MTF - MONTH', None, 156, 'Not Specified'),
#  ('PG', 'XPOM', 'PNGX MARKETS LIMITED', 'PNGX', 157, 'Not Specified'),
#  ('ES', 'GROW', 'BME GROWTH MARKET', None, 158, 'Not Specified'),
#  ('US', 'CLST', 'CLEAR STREET', 'CLST', 159, 'USD'),
#  ('AT', 'LLAT', 'LIECHTENSTEINISCHE LANDESBANK (OSTERREICH) AG', None, 160, 'Not Specified'),
#  ('US', 'EPRD', 'MIAX PEARL EQUITIES EXCHANGE DARK', 'EPRD', 161, 'USD'),
#  ('HK', 'GSPL', 'GS PRINCIPAL LIQUIDITY ASIA', None, 162, 'Not Specified'),
#  ('IT', 'IMMH', 'IMMH - INTESA SANPAOLO', None, 163, 'Not Specified'),
#  ('GB', 'AQSE', 'AQUIS STOCK EXCHANGE', 'AQSE', 164, 'GBP'),
#  ('SG', 'ENMS', 'EURONEXT MARKETS SINGAPORE PTE. LTD.', None, 165, 'Not Specified'),
#  ('US', 'FAST', 'EURONEXT FX', None, 166, 'USD'),
#  ('FR', 'TLCM', 'LOUIS CAPITAL MARKETS EU', None, 167, 'Not Specified'),
#  ('GB', 'ILCM', 'LOUIS CAPITAL MARKETS UK', None, 168, 'GBP'),
#  ('GB', 'LELE', 'LEDGEREDGE', None, 169, 'GBP'),
#  ('IN', 'MCXX', 'METROPOLITAN STOCK EXCHANGE OF INDIA LIMITED', None, 170, 'Not Specified'),
#  ('US', 'MEMD', 'MEMX LLC DARK', 'MEMXDARK', 171, 'USD'),
#  ('GB', 'EBSO', 'NEX SEF - RFQ - FX PRODUCTS FOR ASSET MANAGERS', None, 172, 'GBP'),
#  ('SE', 'PEPW', 'PEPINS - MTF', None, 173, 'Not Specified'),
#  ('GB', 'WFLB', 'WELLS FARGO BANK NA - LONDON BRANCH', None, 174, 'GBP'),
#  ('FR', 'WFSE', 'WELLS FARGO SECURITIES EUROPE, S.A.', 'WFSE', 175, 'Not Specified'),
#  ('US', 'VNDM', 'WALL STREET ACCESS NYC - VNDM', 'VNDM', 176, 'USD'),
#  ('US', 'WABR', 'WALL STREET ACCESS NYC', 'WABR', 177, 'USD'),
#  ('SG', 'XSCA', 'SINGAPORE CATALIST MARKET', None, 178, 'Not Specified'),
#  ('US', 'TMCC', 'ICE TMC', None, 179, 'USD'),
#  ('IE', 'EDBT', 'EURONEXT DUBLIN - TRADED BONDS', None, 180, 'Not Specified'),
#  ('IE', 'EDGL', 'GLOBAL EXCHANGE MARKET - TRADED BONDS', None, 181, 'Not Specified'),
#  ('IT', 'ETLX', 'EUROTLX', None, 182, 'Not Specified'),
#  ('HK', 'BASP', 'BANK OF AMERICA SECURITIES EQUITY SWAP - SYNTHETIC PRICE SOURCE', None, 183, 'Not Specified'),
#  ('US', 'BTEQ', 'BROKERTEC AMERICAS LLC - RFQ PLATFORM', 'US QUOTE', 184, 'USD'),
#  ('IE', 'EQSE', 'EQUILEND LIMITED - SWAPS', None, 185, 'Not Specified'),
#  ('US', 'VABD', 'ICE BONDPOINT', None, 186, 'USD'),
#  ('US', 'IMCC', 'ICE CREDIT TRADE', None, 187, 'USD'),
#  ('GB', 'NBFL', 'NATIONAL BANK FINANCIAL INC.', 'NBF', 188, 'GBP'),
#  ('GB', 'NEXT', 'AQSE TRADING (EQUITY)', None, 189, 'GBP'),
#  ('GB', 'NEXN', 'AQSE TRADING (NON-EQUITY)', None, 190, 'GBP'),
#  ('GB', 'NEXF', 'AQSE GROWTH MARKET (NON-EQUITY)', None, 191, 'GBP'),
#  ('GB', 'NEXX', 'AQUIS STOCK EXCHANGE', None, 192, 'GBP'),
#  ('GB', 'NEXG', 'AQSE GROWTH MARKET (EQUITY)', None, 193, 'GBP'),
#  ('GB', 'NEXL', 'AQSE MAIN MARKET (EQUITY)', None, 194, 'GBP'),
#  ('GB', 'NEXD', 'AQSE MAIN MARKET (NON-EQUITY)', None, 195, 'GBP'),
#  ('SE', 'XNDX', 'NORDIC DERIVATIVES EXCHANGE', 'NDX', 196, 'Not Specified'),
#  ('SE', 'XNMR', 'NORDIC MTF REPORTING', None, 197, 'Not Specified'),
#  ('GB', 'MAXD', 'MAX MARKETS LIMITED', None, 198, 'GBP'),
#  ('SG', 'BTBS', 'BLOOMBERG TRADEBOOK SINGAPORE PTE LTD', None, 199, 'Not Specified'),
#  ('FI', 'AXSI', 'ALEXANDRIA PANKKIIRILIIKE OYJ', None, 200, 'Not Specified'),
#  ('SI', 'SKBB', 'SKB BANKA D.D. LJUBLJANA', None, 201, 'Not Specified'),
#  ('BG', 'BDSK', 'DSK BANK EAD', None, 202, 'Not Specified'),
#  ('AE', 'DEXE', 'DEX LIMITED', None, 203, 'Not Specified'),
#  ('RO', 'OTPR', 'OTP BANK ROMANIA SA', None, 204, 'Not Specified'),
#  ('JP', 'SBIU', 'JAPANNEXT - U - MARKET', None, 205, 'Not Specified'),
#  ('JP', 'XSBI', 'JAPANNEXT - X - MARKET', None, 206, 'Not Specified'),
#  ('JP', 'SBIV', 'JAPANNEXT - VWAP CROSSING', None, 207, 'Not Specified'),
#  ('JP', 'SBIJ', 'JAPANNEXT - J - MARKET', None, 208, 'Not Specified'),
#  ('HR', 'XOTP', 'OTP BANKA D.D.', None, 209, 'Not Specified'),
#  ('GB', 'EQSL', 'EQUILEND EUROPE LIMITED - SWAPS', None, 210, 'GBP'),
#  ('ZA', 'JSER', 'JSE REPO MARKET', None, 211, 'Not Specified'),
#  ('MZ', 'XBVM', 'MOZAMBIQUE STOCK  EXCHANGE', 'BVM', 212, 'Not Specified'),
#  ('GR', 'HESP', 'HENEX ELECTRICITY SPOT MARKET', 'HENEX', 213, 'Not Specified'),
#  ('GR', 'HEDE', 'HENEX FINANCIAL ENERGY MARKET - DERIVATIVES MARKET', 'HENEX', 214, 'Not Specified'),
#  ('IE', 'MAQE', 'MACQUARIE BANK EUROPE DESIGNATED ACTIVITY COMPANY', None, 215, 'Not Specified'),
#  ('US', 'MEMX', 'MEMX LLC EQUITIES', 'MEMX', 216, 'USD'),
#  ('PL', 'PARK', 'PARKER POLAND SP. ZO.O.', None, 217, 'Not Specified'),
#  ('US', 'PJCX', 'PIPER SANDLER AND CO. - ATS', None, 218, 'USD'),
#  ('US', 'PIPR', 'PIPER SANDLER AND CO.', None, 219, 'USD'),
#  ('GB', 'SKYX', 'SKYTRA', None, 220, 'GBP'),
#  ('ES', 'CIMA', 'CIMD S.V. S.A. - APPROVED PUBLICATION ARRANGEMENT', None, 221, 'Not Specified'),
#  ('AE', 'GLOM', 'GLOMAX EXCHANGE LTD', None, 222, 'Not Specified'),
#  ('US', 'TRAI', 'TRAIANA INC', None, 223, 'USD'),
#  ('HR', 'XZAM', 'THE ZAGREB STOCK EXCHANGE MTF', None, 224, 'Not Specified'),
#  ('CH', 'CBOE', 'CBOE FX NDFS', None, 225, 'Not Specified'),
#  ('DE', 'CGEE', 'CITI MATCH DE CONTRA LIQUIDITY', None, 226, 'EUR'),
#  ('DE', 'CGEC', 'CITIGROUP GLOBAL MARKETS  EUROPE AG - EMEA LIQUIDITY HUB', None, 227, 'EUR'),
#  ('GB', 'CGME', 'CITI MATCH - GB', None, 228, 'GBP'),
#  ('GB', 'CGMC', 'CITIGROUP GLOBAL MARKETS  LIMITED - EMEA LIQUIDITY HUB', None, 229, 'GBP'),
#  ('US', 'COHR', 'COMHAR CAPITAL MARKETS, LLC', None, 230, 'USD'),
#  ('NL', 'NEXY', 'EBS MTF - RFQ - FOR CORPORATES TRADING FX PRODUCTS', None, 231, 'Not Specified'),
#  ('US', 'STFU', 'STIFEL, NICOLAUS AND COMPANY, INCORPORATED', 'STFL', 232, 'USD'),
#  ('US', 'STFX', 'STIFEL, NICOLAUS AND COMPANY, INCORPORATED', 'STFL', 233, 'USD'),
#  ('GB', 'TRQS', 'TURQUOISE SWAPMATCH', None, 234, 'GBP'),
#  ('CH', 'XICB', 'SIX CORPORATE BONDS AG', 'SIX', 235, 'Not Specified'),
#  ('GB', 'XLCH', 'LCH LTD', None, 236, 'GBP'),
#  ('GB', 'CLCH', 'LCH LTD - CROSS NETTING', None, 237, 'GBP'),
#  ('GB', 'BUYN', 'LCH LTD - BUY IN', None, 238, 'GBP'),
#  ('US', 'ATDF', 'AUTOMATED TRADING DESK FINANCIAL SERVICES, LLC', 'ATDF', 239, 'USD'),
#  ('BG', 'BGHX', 'BALKAN GAS HUB EAD', None, 240, 'Not Specified'),
#  ('US', 'CORE', 'CITIGROUP AGENCY OPTION AND EQUITIES ROUTING ENGINE', None, 241, 'USD'),
#  ('US', 'CICX', 'CITI CROSS', 'CX', 242, 'USD'),
#  ('CZ', 'CSAS', 'CESKA SPORITELNA, A.S.', None, 243, 'Not Specified'),
#  ('US', 'LTSE', 'LONG-TERM STOCK EXCHANGE, INC.', 'LTSE', 244, 'USD'),
#  ('SG', 'MALM', 'MARKETAXESS SINGAPORE PTE LIMITED - LIVE MARKETS', None, 245, 'Not Specified'),
#  ('DE', 'XPSF', 'EUROPEAN ENERGY EXCHANGE - REGULATED GAS MARKET', None, 246, 'EUR'),
#  ('DE', 'XPOT', 'EUROPEAN ENERGY EXCHANGE - OTF GAS MARKET', None, 247, 'EUR'),
#  ('AU', 'XFEX', 'FEX GLOBAL', 'FEX', 248, 'Not Specified'),
#  ('US', 'CALH', 'CLSA AMERICAS - LIQUIDITY HUB', None, 249, 'USD'),
#  ('PT', 'OMIP', 'OMIP - POLO PORTUGUES, S.G.M.R., S.A. / OMIP DERIVATIVES MARKET', 'OMIP', 250, 'Not Specified'),
#  ('PT', 'XLIS', 'EURONEXT - EURONEXT LISBON', None, 251, 'Not Specified'),
#  ('US', 'CSLP', 'CREDIT SUISSE LIGHT POOL', None, 252, 'USD'),
#  ('GB', 'DAUK', 'DANSKE BANK A/S - LONDON BRANCH', None, 253, 'GBP'),
#  ('GB', 'BSLB', 'BANCO SANTANDER, LONDON BRANCH', None, 254, 'GBP'),
#  ('IE', 'CFIL', 'CANTOR FITZGERALD IRELAND LIMITED', None, 255, 'Not Specified'),
#  ('GB', 'CGMU', 'CITI MATCH GB CONTRA LIQUIDITY', None, 256, 'GBP'),
#  ('US', 'CSCL', 'CREDIT SUISSE CLOSEX', None, 257, 'USD'),
#  ('US', 'CSVW', 'CREDIT SUISSE VWAPX', None, 258, 'USD'),
#  ('GB', 'RBCM', 'RBC - ROYAL BANK OF CANADA', 'RBC', 259, 'GBP'),
#  ('US', 'THRE', 'REFINITIV US SEF LLC', 'RSEF', 260, 'USD'),
#  ('US', 'WEED', 'WEEDEN AND CO MARKETS', None, 261, 'USD'),
#  ('US', 'XWEE', 'WEEDEN ATS', None, 262, 'USD'),
#  ('US', 'BKKT', 'BAKKT', None, 263, 'USD'),
#  ('GB', 'UKRE', 'TP ICAP UK MTF - REGISTRATION', None, 264, 'GBP'),
#  ('GB', 'UKOR', 'TP ICAP UK MTF - ORDERBOOK', None, 265, 'GBP'),
#  ('GB', 'IUOB', 'ICAP UK OTF - ORDERBOOK', None, 266, 'GBP'),
#  ('GB', 'TUOB', 'TP UK OTF - ORDERBOOK', None, 267, 'GBP'),
#  ('US', 'XPUS', 'XP INVESTMENTS US, LLC', None, 268, 'USD'),
#  ('IE', 'BMLS', 'BANK OF AMERICA MERRILL LYNCH INTERNATIONAL BANK DESIGNATED ACTIVITY COMPANY - SYSTEMATIC INTERNALISER', 'BAMLI DAC', 269, 'Not Specified'),
#  ('IE', 'BMLI', 'BANK OF AMERICA MERRILL LYNCH INTERNATIONAL BANK DESIGNATED ACTIVITY COMPANY', 'BAMLI DAC', 270, 'Not Specified'),
#  ('IE', 'BMSI', 'BANK OF AMERICA MERRILL LYNCH INTERNATIONAL BANK DESIGNATED ACTIVITY COMPANY', 'BAMLI', 271, 'Not Specified'),
#  ('IE', 'BMLX', 'BANK OF AMERICA MERRILL LYNCH INTERNATIONAL BANK DESIGNATED ACTIVITY COMPANY', 'BAMLI', 272, 'Not Specified'),
#  ('GB', 'SGMZ', 'SIGMA X MTF - NEGOTIATED TRADE', None, 273, 'GBP'),
#  ('GB', 'PFXD', 'PARNDF', None, 274, 'GBP'),
#  ('GB', 'TRQC', 'TURQUOISE NYLON CLEARED CONTRACT', None, 275, 'GBP'),
#  ('GB', 'GSBX', 'GOLDMAN SACHS INTERNATIONAL - SIGMA BCN', None, 276, 'GBP'),
#  ('IE', 'ITGL', 'POSIT MTF', 'POSIT', 277, 'Not Specified'),
#  ('JO', 'XAMM', 'AMMAN STOCK EXCHANGE', 'ASE', 278, 'Not Specified'),
#  ('JO', 'AMNL', 'AMMAN STOCK EXCHANGE - NON-LISTED SECURITIES MARKET', 'ASE', 279, 'Not Specified'),
#  ('HU', 'BETA', 'BETA MARKET', None, 280, 'Not Specified'),
#  ('GB', 'VFGB', 'VIRTU FINANCIAL IRELAND LIMITED (LONDON BRANCH)', None, 281, 'GBP'),
#  ('GB', 'VFUK', 'VIRTU FINANCIAL IRELAND LIMITED (LONDON BRANCH)', None, 282, 'GBP'),
#  ('LT', 'SEBL', 'SEB LITHUANIA', None, 283, 'Not Specified'),
#  ('GB', 'XPOL', 'POSIT DARK UK', None, 284, 'GBP'),
#  ('GB', 'XPAL', 'POSIT AUCTION UK', None, 285, 'GBP'),
#  ('GB', 'VIUK', 'POSIT UK', None, 286, 'GBP'),
#  ('US', 'ASPI', 'INTELLIGENTCROSS ASPEN INVERTED', None, 287, 'USD'),
#  ('US', 'ASMT', 'INTELLIGENTCROSS ASPEN MAKER/TAKER', None, 288, 'USD'),
#  ('US', 'ASPN', 'INTELLIGENTCROSS ASPEN INTELLIGENT BID/OFFER', None, 289, 'USD'),
#  ('US', 'CISD', 'NYSE NATIONAL, INC. - DARK', None, 290, 'USD'),
#  ('DE', 'CDSI', 'CREDIT SUISSE (DEUTSCHLAND) AG', 'CSD SI', 291, 'EUR'),
#  ('NL', 'RESF', 'EBS MTF - RESET SEGMENT', None, 292, 'Not Specified'),
#  ('NL', 'EBSF', 'EBS MTF - FX PRODUCTS - RFQ SEGMENT', None, 293, 'Not Specified'),
#  ('BM', '24EX', '24 EXCHANGE', '24EX', 294, 'Not Specified'),
#  ('GB', 'BBSX', 'BB SECURITIES LTD', None, 295, 'GBP'),
#  ('GB', 'JLSI', 'JUMP LIQUIDITY', None, 296, 'GBP'),
#  ('GB', 'SCOT', 'SCOTTISH STOCK EXCHANGE', 'SSX', 297, 'GBP'),
#  ('DE', 'XDEX', 'BOERSE STUTTGART - DIGITAL EXCHANGE', None, 298, 'EUR'),
#  ('ES', 'DOWE', 'DOWGATE EURO GOVERNMENT BONDS', None, 299, 'Not Specified'),
#  ('DE', 'SPEX', 'SPECTRUM MARKETS', None, 300, 'EUR'),
#  ('AE', 'IFAD', 'ICE FUTURES ABU DHABI', None, 301, 'Not Specified'),
#  ('US', 'JLQD', 'JUMP LIQUIDITY - MULTI-ASSET PLATFORM', 'JLQD', 302, 'USD'),
#  ('US', 'LAMP', 'LAMPOST CAPITAL', 'LAMP', 303, 'USD'),
#  ('US', 'RCMA', 'RBC CAPITAL MARKETS ARBITRAGE S.A.', None, 304, 'USD'),
#  ('PL', 'WOPO', 'WARSAW STOCK EXCHANGE - SPO BOOK BUILDING', 'WSE', 305, 'Not Specified'),
#  ('NL', 'IEBS', 'EBS MTF - RFQ - FX PRODUCTS FOR ASSET MANAGERS', None, 306, 'Not Specified'),
#  ('US', 'ERIS', 'ERSX', 'ERSX', 307, 'USD'),
#  ('FR', 'MKTF', 'MARKET SECURITIES (FRANCE) SA', None, 308, 'Not Specified'),
#  ('US', 'MKAA', 'MARKETAXESS ATS', None, 309, 'USD'),
#  ('GB', 'XSGB', 'SOCIETE GENERALE (LONDON BRANCH)', None, 310, 'GBP'),
#  ('US', 'YKNA', 'COMHAR CAPITAL MARKETS, LLC - US EQUITIES', None, 311, 'USD'),
#  ('DE', 'CGET', 'CITIGROUP GLOBAL MARKETS  EUROPE AG - EMEA TRADING', None, 312, 'EUR'),
#  ('DE', 'CSDA', 'CREDIT SUISSE AKTIENGESELLSCHAFT', 'CSD', 313, 'EUR'),
#  ('ES', 'DOWM', 'DOWGATE - MTF (MADRID)', None, 314, 'Not Specified'),
#  ('CN', 'GSXC', 'GSX CHINA', None, 315, 'Not Specified'),
#  ('KR', 'GSXK', 'GSX KOREA', None, 316, 'Not Specified'),
#  ('TW', 'GSXT', 'GSX TAIWAN', None, 317, 'Not Specified'),
#  ('GB', 'VAGM', 'VIRTUAL AUCTION GLOBAL MARKETS - MTF', 'VAGM MTF', 318, 'GBP'),
#  ('DE', 'XEUB', 'EUREX BONDS', None, 319, 'EUR'),
#  ('GB', 'BMCM', 'BMO CAPITAL MARKETS LIMITED', 'ST', 320, 'GBP'),
#  ('MT', 'EWSM', 'EUROPEAN WHOLESALE SECURITIES MARKET', 'EWSM', 321, 'Not Specified'),
#  ('DK', 'GXGR', 'GXG MARKETS A/S', 'DANSK AMP', 322, 'Not Specified'),
#  ('DK', 'GXGM', 'GXG MTF', None, 323, 'Not Specified'),
#  ('DK', 'GXGF', 'GXG MTF FIRST QUOTE', None, 324, 'Not Specified'),
#  ('SE', 'NSME', 'NORDIC SME', 'NGM', 325, 'Not Specified'),
#  ('GR', 'ABFI', 'ALPHA BANK', None, 326, 'Not Specified'),
#  ('NL', 'BEUP', 'CBOE EUROPE - DXE PERIODIC (NL)', 'CBOE EU DXE PERIODIC', 327, 'Not Specified'),
#  ('NL', 'BEUF', 'CBOE EUROPE - BXE OFF-BOOK (NL)', 'CBOE EU BXE OFF BOOK', 328, 'Not Specified'),
#  ('NL', 'CEUD', 'CBOE EUROPE - DXE DARK ORDER BOOK (NL)', 'CBOE EU DXE DARK', 329, 'Not Specified'),
#  ('NL', 'BEUD', 'CBOE EUROPE - BXE DARK ORDER BOOK (NL)', 'CBOE EU DARK', 330, 'Not Specified'),
#  ('NL', 'CEUX', 'CBOE EUROPE - DXE ORDER BOOKS (NL)', 'CBOE EU DXE', 331, 'Not Specified'),
#  ('NL', 'CEUO', 'CBOE EUROPE - DXE OFF-BOOK (NL)', 'CBOE EU DXE OFF BOOK', 332, 'Not Specified'),
#  ('NL', 'BEUE', 'CBOE EUROPE - BXE ORDER BOOKS (NL)', 'CBOE EU BXE', 333, 'Not Specified'),
#  ('US', 'DASH', 'DASH ATS', None, 334, 'USD'),
#  ('RU', 'MISX', 'MOSCOW EXCHANGE - ALL MARKETS', 'MOEX', 335, 'Not Specified'),
#  ('HU', 'XBND', 'BUDAPEST STOCK EXCHANGE - XBOND', None, 336, 'Not Specified'),
#  ('US', 'BLKX', 'INSTINET BLOCKCROSS ATS', 'BLKX', 337, 'USD'),
#  ('PL', 'PLPD', 'WARSAW STOCK EXCHANGE/POLISH POWER EXCHANGE/REGULATED MARKET', 'WSE', 338, 'Not Specified'),
#  ('JP', 'BAJD', 'BANK OF AMERICA MERRILL LYNCH - JAPAN INSTINCT X', None, 339, 'Not Specified'),
#  ('JP', 'NMSX', 'NOMURA - EXTERNAL CROSSING PLATFORM', None, 340, 'Not Specified'),
#  ('GB', 'XLOD', 'LONDON STOCK EXCHANGE - CURVEGLOBAL MARKETS', 'LSE', 341, 'GBP'),
#  ('US', 'LAFX', 'LAVAFX', None, 342, 'USD'),
#  ('CA', 'NEOE', 'NEO EXCHANGE - NEO-L (MARKET BY ORDER)', 'NEO-L', 343, 'Not Specified'),
#  ('CA', 'NEOD', 'NEO EXCHANGE - NEO-D (DARK)', 'NEO-D', 344, 'Not Specified'),
#  ('CA', 'NEON', 'NEO EXCHANGE - NEO-N (MARKET BY PRICE)', 'NEO-N', 345, 'Not Specified'),
#  ('CA', 'NEOC', 'NEO CONNECT', 'NEO CONNECT', 346, 'Not Specified'),
#  ('SC', 'TRPX', 'MERJ EXCHANGE LIMITED', 'MERJ', 347, 'Not Specified'),
#  ('CZ', 'KOME', 'KOMERCNI BANKA, A.S.', None, 348, 'Not Specified'),
#  ('US', 'TRCX', 'TOWER RESEARCH CAPITAL TRCX', None, 349, 'USD'),
#  ('GR', 'ERBX', 'EUROBANK', None, 350, 'Not Specified'),
#  ('NL', 'FLTR', 'FLOW TRADERS - SYSTEMATIC INTERNALISER', None, 351, 'Not Specified'),
#  ('ES', 'IBER', 'IBERCAJA BANCO SA', 'IBERCAJA', 352, 'Not Specified'),
#  ('ES', 'ALLT', 'ALLT - OTF', 'ALLT-OTF', 353, 'Not Specified'),
#  ('GB', 'BATE', 'CBOE EUROPE - BXE ORDER BOOKS', 'CBOE EUROPE', 354, 'GBP'),
#  ('GB', 'BATF', 'CBOE EUROPE - BXE OFF-BOOK', 'CBOE OFF-BOOK', 355, 'GBP'),
#  ('GB', 'BATD', 'CBOE EUROPE - BXE DARK ORDER BOOK', 'CBOE DARK', 356, 'GBP'),
#  ('LU', 'BILU', 'BANQUE INTERNATIONALE A LUXEMBOURG S.A.', 'BIL', 357, 'Not Specified'),
#  ('NL', 'BTQE', 'CME AMSTERDAM B.V. - RFQ TRADING PROTOCOL', None, 358, 'Not Specified'),
#  ('GB', 'BTQG', 'BROKERTEC EUROPE LIMITED - RFQ TRADING PROTOCOL', 'BEM', 359, 'GBP'),
#  ('SK', 'CBSK', 'CESKOSLOVENSKA OBCHODNA BANKA, A.S.', 'CSOB SK', 360, 'Not Specified'),
#  ('US', 'CODA', 'CODA MARKETS - MICRO AND BLOCK', 'CODA', 361, 'USD'),
#  ('US', 'PDQX', 'CODA MARKETS', 'PDQX', 362, 'USD'),
#  ('DE', 'SMBD', 'SUMITOMO MITSUI BANKING CORPORATION - DUESSELDORF BRANCH', None, 363, 'EUR'),
#  ('GB', 'STFL', 'STIFEL NICOLAUS EUROPE LIMITED', None, 364, 'GBP'),
#  ('GB', 'XALT', 'ALTEX - ATS', None, 365, 'GBP'),
#  ('SK', 'EBRA', 'BRATISLAVA STOCK EXCHANGE - MTF', None, 366, 'Not Specified'),
#  ('RO', 'XCAN', 'CAN - ATS', None, 367, 'Not Specified'),
#  ('CZ', 'XRMO', 'RM-SYSTEM CZECH STOCK EXCHANGE - MTF', 'RMS CZ', 368, 'Not Specified'),
#  ('PL', 'XNCO', 'WARSAW STOCK EXCHANGE/ EQUITIES/NEW CONNECT - MTF', None, 369, 'Not Specified'),
#  ('US', 'KNMX', 'KNIGHT MATCH ATS', None, 370, 'USD'),
#  ('US', 'SAGE', 'SAGETRADER', None, 371, 'USD'),
#  ('GB', 'ARCH', 'ARCHAX', None, 372, 'GBP'),
#  ('US', 'EXPM', 'EXPERT MARKET', None, 373, 'USD'),
#  ('BE', 'TNLK', 'EURONEXT BLOCKS', None, 374, 'Not Specified'),
#  ('CA', 'XDRK', 'TORONTO STOCK EXCHANGE - DRK', 'TSX DRK', 375, 'Not Specified'),
#  ('CA', 'VDRK', 'TSX VENTURE EXCHANGE - DRK', 'TSXV DRK', 376, 'Not Specified'),
#  ('FR', 'GFPO', 'GFI PARIS - OTF', None, 377, 'Not Specified'),
#  ('US', 'JPMS', 'JPMS, LLC', None, 378, 'USD'),
#  ('GB', 'SNUK', 'SANTANDER UK', 'SNUK', 379, 'GBP'),
#  ('US', 'ARKX', 'ARKONIS', 'ARKX', 380, 'USD'),
#  ('US', 'PUMX', 'PUMA CAPITAL, LLC - OPTIONS', 'PUMA', 381, 'USD'),
#  ('VC', 'SVXI', 'SAINT VINCENT AND THE GRENADINES SECURITIES EXCHANGE', 'SVGEX', 382, 'Not Specified'),
#  ('DE', 'VWDA', 'VWD - APA SERVICE', None, 383, 'EUR'),
#  ('AL', 'XALS', 'ALBANIA SECURITIES EXCHANGE', 'ALSE', 384, 'Not Specified'),
#  ('GB', 'BGFU', 'BERENBERG FIXED INCOME UK', 'BGFU', 385, 'GBP'),
#  ('GB', 'CGMG', 'CITIGROUP GLOBAL MARKETS EUROPE AG - LONDON BRANCH', None, 386, 'GBP'),
#  ('US', 'PUMA', 'PUMA CAPITAL, LLC', 'PUMA', 387, 'USD'),
#  ('ZA', '4AXE', '4 AFRICA EXCHANGE (PTY) LTD', None, 388, 'Not Specified'),
#  ('GB', 'MCZK', 'MTS CZECH REPUBLIC', None, 389, 'GBP'),
#  ('GB', 'HUNG', 'MTS HUNGARY', None, 390, 'GBP'),
#  ('GB', 'EMTS', 'EBM', 'EMTS', 391, 'GBP'),
#  ('GB', 'MTSA', 'MTS AUSTRIA', None, 392, 'GBP'),
#  ('GB', 'GMTS', 'MTS GERMANY', None, 393, 'GBP'),
#  ('GB', 'MTSG', 'MTS GREECE', None, 394, 'GBP'),
#  ('GB', 'IMTS', 'MTS IRELAND', None, 395, 'GBP'),
#  ('GB', 'RMTS', 'MTS ISRAEL', None, 396, 'GBP'),
#  ('GB', 'AMTS', 'MTS NETHERLANDS', None, 397, 'GBP'),
#  ('GB', 'PORT', 'MTS PORTUGAL', 'PTE', 398, 'GBP'),
#  ('GB', 'SLKK', 'MTS SLOVAKIA', None, 399, 'GBP'),
#  ('GB', 'VMTS', 'MTS SLOVENIA', None, 400, 'GBP'),
#  ('GB', 'SMTS', 'MTS SPAIN', None, 401, 'GBP'),
#  ('HU', 'EBHU', 'ERSTE BANK HUNGARY ZRT.', None, 402, 'Not Specified'),
#  ('NL', 'EBSI', 'EBS MTF - RFQ - FOR ASSET MANAGERS TRADING FX PRODUCTS', None, 403, 'Not Specified'),
#  ('NL', 'RESE', 'EBS MTF - RESET', None, 404, 'Not Specified'),
#  ('NL', 'EBSD', 'EBS MTF - RFQ - FOR THE TRADING OF FX PRODUCTS', None, 405, 'Not Specified'),
#  ('CH', 'EUSP', 'EUREX OTC SPOT MARKET', None, 406, 'Not Specified'),
#  ('CH', 'EUCH', 'EUREX ZURICH', None, 407, 'Not Specified'),
#  ('CH', 'EURM', 'EUREX REPO MARKET', None, 408, 'Not Specified'),
#  ('CH', 'EUSC', 'EUREX CH SECLEND MARKET', None, 409, 'Not Specified'),
#  ('GB', 'FNUK', 'FINANTIA UK LIMITED', None, 410, 'GBP'),
#  ('ES', 'XMFX', 'MEFF FX FINANCIAL DERIVATIVES', None, 411, 'Not Specified'),
#  ('GB', 'TRFW', 'REFINITIV TRANSACTION SERVICES LIMITED - FORWARDS MATCHING', None, 412, 'GBP'),
#  ('HU', 'UCHU', 'UNICREDIT BANK HUNGARY ZRT.', None, 413, 'Not Specified'),
#  ('GB', 'CBNL', 'CITIBANK N.A. LONDON', None, 414, 'GBP'),
#  ('US', 'FTUS', 'FLOW TRADERS U.S LLC', None, 415, 'USD'),
#  ('GB', 'TEEG', 'TULLETT PREBON SECURITIES - OTF - EUROPEAN GOVERNMENT BONDS', None, 416, 'GBP'),
#  ('GB', 'BGUK', 'BERENBERG  UK', 'BGUK', 417, 'GBP'),
#  ('GB', 'CLVE', 'VERTO MTF', None, 418, 'GBP'),
#  ('US', 'NLAX', 'CLEARPOOL EXECUTION SERVICES, LLC - NATURAL LIQUIDITY ALLIANCE', None, 419, 'USD'),
#  ('US', 'CPGX', 'CLEARPOOL EXECUTION SERVICES, LLC', None, 420, 'USD'),
#  ('IE', 'CEPL', 'CITIBANK EUROPE PLC', None, 421, 'Not Specified'),
#  ('GB', 'CEPU', 'CITIBANK EUROPE PLC - LONDON BRANCH', None, 422, 'GBP'),
#  ('US', 'DBAB', 'DEUTSCHE BANK SECURITIES INC.', None, 423, 'USD'),
#  ('US', 'OTCN', 'OTC LINK ECN', None, 424, 'USD'),
#  ('GB', 'RTSL', 'REFINITIV TRANSACTIONS SERVICES LIMITED', 'RTSL', 425, 'GBP'),
#  ('GB', 'TRAL', 'REFINITIV TRANSACTIONS SERVICES LIMITED - FXALL RFQ', None, 426, 'GBP'),
#  ('IE', 'TDGF', 'TD SECURITIES', None, 427, 'Not Specified'),
#  ('GB', 'UBSB', 'UBS AG LONDON BRANCH - TRADING', None, 428, 'GBP'),
#  ('DE', 'UBSD', 'UBS EUROPE SE', None, 429, 'EUR'),
#  ('GB', 'UBSE', 'UBS PIN (EMEA)', None, 430, 'GBP'),
#  ('DE', 'UBSI', 'UBS EUROPE SE', None, 431, 'EUR'),
#  ('DE', 'UBSL', 'UBS EUROPE SE - TRADING', None, 432, 'EUR'),
#  ('AT', 'WBGF', 'WIENER BOERSE AG GEREGELTER FREIVERKEHR (SECOND REGULATED MARKET)', None, 433, 'Not Specified'),
#  ('DE', 'XETV', 'XETRA - FREIVERKEHR - OFF-BOOK', None, 434, 'EUR'),
#  ('DE', 'XETW', 'XETRA - SCALE - OFF-BOOK', None, 435, 'EUR'),
#  ('DE', 'XETU', 'XETRA - REGULIERTERMARKT - OFF-BOOK', None, 436, 'EUR'),
#  ('DE', 'FRAV', 'BOERSE FRANKFURT - FREIVERKEHR - OFF-BOOK', None, 437, 'EUR'),
#  ('DE', 'FRAW', 'BOERSE FRANKFURT - SCALE - OFF-BOOK', None, 438, 'EUR'),
#  ('DE', 'FRAU', 'BOERSE FRANKFURT - REGULIERTERMARKT - OFF-BOOK', None, 439, 'EUR'),
#  ('PT', 'BFPT', 'BANCO FINANTIA S.A.', None, 440, 'Not Specified'),
#  ('HU', 'CONC', 'CONCORDE SECURITIES LTD.', None, 441, 'Not Specified'),
#  ('IR', 'IFBX', 'IRAN FARA BOURSE', 'IFB', 442, 'Not Specified'),
#  ('GB', 'IPXW', 'IPSX WHOLESALE', 'IPSX', 443, 'GBP'),
#  ('US', 'ZERO', 'ZERO HASH', None, 444, 'USD'),
#  ('US', 'SCXS', 'SEED SEF', None, 445, 'USD'),
#  ('US', 'SCXO', 'SEED CX', 'SEED CX', 446, 'USD'),
#  ('US', 'SCXM', 'SEED DIGITAL COMMODITIES MARKET', None, 447, 'USD'),
#  ('SG', 'SYFX', 'SYNOPTION', 'SYFX', 448, 'Not Specified'),
#  ('GB', 'SSIL', 'STATE STREET BANK INTERNATIONAL FX - LONDON BRANCH', 'SSIL', 449, 'GBP'),
#  ('FR', 'TPIR', 'TP ICAP EU - MTF - REGISTRATION', None, 450, 'Not Specified'),
#  ('US', 'XCHI', 'NYSE CHICAGO, INC.', 'CHX', 451, 'USD'),
#  ('US', 'XCIS', 'NYSE NATIONAL, INC.', 'NSX', 452, 'USD'),
#  ('NL', 'MANL', 'MARKETAXESS NL B.V.', None, 453, 'Not Specified'),
#  ('CZ', 'CELP', 'CESKOSLOVENSKÁ OBCHODNÍ BANKA, A.S. - OTHER LIQUIDITY PROVIDER (OLP)', 'CSOB', 454, 'Not Specified'),
#  ('GB', 'BETX', 'BET OTC BILAT COMMODITY DERIVATIVES', 'BET', 455, 'GBP'),
#  ('GB', 'BTLX', 'BTL OTC BILAT COMMODITY DERIVATIVES', 'BTL', 456, 'GBP'),
#  ('KZ', 'CCEX', 'CASPY COMMODITY EXCHANGE', None, 457, 'Not Specified'),
#  ('BG', 'ZBUL', 'BULGARIAN STOCK EXCHANGE - MAIN MARKET', None, 458, 'Not Specified'),
#  ('GB', 'IMSB', 'TP ICAP UK MTF - CORPORATE BONDS AND SECURITIES DEBT', None, 459, 'GBP'),
#  ('FR', 'AQEU', 'AQUIS EXCHANGE EUROPE', None, 460, 'Not Specified'),
#  ('FR', 'AQEA', 'AQUIS EXCHANGE EUROPE AUCTION ON DEMAND (AOD)', None, 461, 'Not Specified'),
#  ('GB', 'AQXA', 'AQUIS EXCHANGE PLC AUCTION ON DEMAND (AOD)', None, 462, 'GBP'),
#  ('GB', 'AQXE', 'AQUIS EXCHANGE PLC', 'AQX', 463, 'GBP'),
#  ('IE', 'BKDM', 'BNY MELLON MARKETS EUROPE LIMITED', 'BNYMEL', 464, 'Not Specified'),
#  ('IT', 'BNLD', 'BANCA NAZIONALE DEL LAVORO SPA', None, 465, 'Not Specified'),
#  ('NL', 'CAVD', 'CAVENDISH MARKETS B.V.', None, 466, 'Not Specified'),
#  ('FR', 'GIPB', 'GOLDMAN SACHS INTERNATIONAL PARIS BRANCH', None, 467, 'Not Specified'),
#  ('FR', 'GSPX', 'GOLDMAN SACHS INTERNATIONAL PARIS BRANCH - SYSTEMATIC INTERNALISER', None, 468, 'Not Specified'),
#  ('GB', 'ICPM', 'TP ICAP UK MTF', None, 469, 'GBP'),
#  ('GB', 'IMGI', 'TP ICAP UK MTF - GILTS', None, 470, 'GBP'),
#  ('GB', 'IMRD', 'TP ICAP UK MTF - INTEREST RATE DERIVATIVES', None, 471, 'GBP'),
#  ('GB', 'IMET', 'TP ICAP UK MTF - EXCHANGE TRADED PRODUCTS', None, 472, 'GBP'),
#  ('GB', 'IMGB', 'TP ICAP UK MTF - GOVERNMENT BONDS EXCLUDING GILTS', None, 473, 'GBP'),
#  ('GB', 'IMMM', 'TP ICAP UK MTF - MONEY MARKET INSTRUMENTS', None, 474, 'GBP'),
#  ('GB', 'IMFD', 'TP ICAP UK MTF - FX DERIVATIVES', None, 475, 'GBP'),
#  ('GB', 'IMCE', 'TP ICAP UK MTF - CASH EQUITY', None, 476, 'GBP'),
#  ('GB', 'IMED', 'TP ICAP UK MTF - EQUITY DERIVATIVES', None, 477, 'GBP'),
#  ('NL', 'JLEU', 'JUMP LIQUIDITY EU EQUITY PLATFORM', None, 478, 'Not Specified'),
#  ('DE', 'SMFF', 'SMBC BANK EU AG', None, 479, 'EUR'),
#  ('NO', 'SPTR', 'SPAREBANK 1 SMN', None, 480, 'Not Specified'),
#  ('FR', 'ELXE', 'ELIXIUM S.A.', None, 481, 'Not Specified'),
#  ('DE', 'SCAG', 'STANDARD CHARTERED BANK AG', None, 482, 'EUR'),
#  ('US', 'SGAS', 'SG AMERICAS SECURITIES, LLC', 'SGAS', 483, 'USD'),
#  ('US', 'SMFE', 'SMALL EXCHANGE, INC - DESIGNATED CONTRACT MARKET', None, 484, 'USD'),
#  ('FR', 'TRXE', 'TRAD-X EUROPE', None, 485, 'Not Specified'),
#  ('BG', 'JBUL', 'BULGARIAN STOCK EXCHANGE - INTERNATIONAL MTF', 'BSE-MTF', 486, 'Not Specified'),
#  ('NL', 'MHBE', 'MIZUHO BANK EUROPE N.V.', None, 487, 'Not Specified'),
#  ('IE', 'CSGI', 'CITADEL SECURITIES FI - EUROPE', None, 488, 'Not Specified'),
#  ('IE', 'EUCC', 'CITADEL CONNECT EUROPE - EU', None, 489, 'Not Specified'),
#  ('DE', 'BLEQ', 'BAYERNLB - EQUITIES MARKET', None, 490, 'EUR'),
#  ('IT', 'BREA', 'BANCA REALE', None, 491, 'Not Specified'),
#  ('IT', 'MCAD', 'MTS CASH DOMESTIC - MTF', None, 492, 'Not Specified'),
#  ('IT', 'EBMX', 'EBM - MTF', None, 493, 'Not Specified'),
#  ('BE', 'ENXB', 'EURONEXT - EASY NEXT', None, 494, 'Not Specified'),
#  ('IE', 'XMSM', 'EURONEXT DUBLIN', None, 495, 'Not Specified'),
#  ('IE', 'XESM', 'EURONEXT GROWTH DUBLIN', None, 496, 'Not Specified'),
#  ('GB', 'UKGD', 'MTS UK', None, 497, 'GBP'),
#  ('FR', 'XTXE', 'XTX MARKETS SAS', None, 498, 'Not Specified'),
#  ('US', 'BLUE', 'PRO SECURITIES ATS', 'PROS', 499, 'USD'),
#  ('NL', 'BTAM', 'CME AMSTERDAM B.V.', None, 500, 'Not Specified'),
#  ('NL', 'CABV', 'CME AMSTERDAM B.V. - APA', None, 501, 'Not Specified'),
#  ('CZ', 'RFBK', 'RAIFFEISENBANK, AS.', 'RBCZ', 502, 'Not Specified'),
#  ('NL', 'TOWR', 'TOWER RESEARCH CAPITAL EUROPE', None, 503, 'Not Specified'),
#  ('BG', 'GBUL', 'BULGARIAN STOCK EXCHANGE - SME GROWTH MARKET BEAM', 'BEAM', 504, 'Not Specified'),
#  ('IT', 'BPAS', 'BANCA PASSADORE', None, 505, 'Not Specified'),
#  ('NL', 'FLWX', 'FLOW TRADERS', None, 506, 'Not Specified'),
#  ('GB', 'TNLL', 'EURONEXT - TRADING FACILITY LONDON', None, 507, 'GBP'),
#  ('LU', 'BLUX', 'BANQUE DE LUXEMBOURG', None, 508, 'Not Specified'),
#  ('LU', 'DBLX', 'DEUTSCHE BANK LUXEMBOURG S.A.', None, 509, 'Not Specified'),
#  ('LU', 'DHLX', 'DEUTSCHE HOLDINGS (LUXEMBOURG) S.A R.L.', None, 510, 'Not Specified'),
#  ('HU', 'KHHU', 'K AND H BANK ZRT', None, 511, 'Not Specified'),
#  ('IE', 'MCID', 'MACQUARIE CAPITAL (IRELAND)', None, 512, 'Not Specified'),
#  ('DE', 'NCME', 'SMBC NIKKO CAPITAL MARKETS EUROPE GMBH', None, 513, 'EUR'),
#  ('GB', 'TRQM', 'TURQUOISE PLATO', None, 514, 'GBP'),
#  ('FR', 'XBLK', 'EURONEXT BLOCK 2', None, 515, 'Not Specified'),
#  ('NL', 'IPNL', 'ISWAP EURO MTF', None, 516, 'Not Specified'),
#  ('NL', 'ISWO', 'ISWAP EURO MTF - ORDERBOOK', None, 517, 'Not Specified'),
#  ('NL', 'ISWP', 'ISWAP EURO MTF', None, 518, 'Not Specified'),
#  ('NL', 'ISWN', 'ISWAP EURO MTF - TRADE REGISTRATION', None, 519, 'Not Specified'),
#  ('NL', 'ISWT', 'ISWAP EURO MTF - TARGETED STREAMING / RFQ', None, 520, 'Not Specified'),
#  ('IE', 'MSEL', 'MAREX SPECTRON EUROPE LIMITED - OTF', 'MSEL OTF', 521, 'Not Specified'),
#  ('GB', 'NCML', 'SMBC NIKKO CAPITAL MARKETS LIMITED', None, 522, 'GBP'),
#  ('IE', 'FXRQ', 'FINANCIAL AND RISK TRANSACTIONS SERVICES IRELAND LIMITED - FXALL RFQ MTF', None, 523, 'Not Specified'),
#  ('IE', 'FXFM', 'FINANCIAL AND RISK TRANSACTIONS SERVICES IRELAND LIMITED - FORWARDS MATCHING', None, 524, 'Not Specified'),
#  ('BG', 'PBUL', 'BULGARIAN STOCK EXCHANGE - APA', None, 525, 'Not Specified'),
#  ('GB', 'XPUK', 'XP INVESTMENTS UK LLP', None, 526, 'GBP'),
#  ('CH', 'CSAG', 'CREDIT SUISSE AG', 'CSA', 527, 'Not Specified'),
#  ('FR', 'XETF', 'EURONEXT ETF ACCESS', None, 528, 'Not Specified'),
#  ('DE', 'GSEI', 'GOLDMAN SACHS BANK EUROPE SE - SYSTEMATIC INTERNALISER', None, 529, 'EUR'),
#  ('DE', 'GSBE', 'GOLDMAN SACHS BANK EUROPE SE', None, 530, 'EUR'),
#  ('IE', 'HREU', 'HRTEU LIMITED', None, 531, 'Not Specified'),
#  ('GB', 'STSI', 'SUN TRADING INTERNATIONAL', None, 532, 'GBP'),
#  ('IT', 'CREM', 'CREDEM BANCA', 'CREDEM SI', 533, 'Not Specified'),
#  ('US', 'DWFI', 'DEALERWEB FIXED INCOME', None, 534, 'USD'),
#  ('PL', 'BNPP', 'BANK BGZ BNP PARIBAS S.A.', None, 535, 'Not Specified'),
#  ('DE', 'CBKC', 'COMMERZBANK  COMMODITY DERIVATIVES', None, 536, 'EUR'),
#  ('HU', 'CIBH', 'CIB BANK', None, 537, 'Not Specified'),
#  ('ES', 'CSMD', 'CREDIT SUISSE BANK (EUROPE), S.A.', 'CSEB', 538, 'Not Specified'),
#  ('ES', 'SIMD', 'CREDIT SUISSE BANK (EUROPE), S.A. - SYSTEMATIC INTERNALISER', None, 539, 'Not Specified'),
#  ('FR', 'GMES', 'GRIFFIN MARKETS EUROPE', None, 540, 'Not Specified'),
#  ('FR', 'GMEO', 'GRIFFIN MARKETS EUROPE - OTF', None, 541, 'Not Specified'),
#  ('LU', 'KBLC', 'QUINTET PRIVATE BANK (EUROPE) S.A. - EURO COMMERCIAL PAPERS', None, 542, 'Not Specified'),
#  ('LU', 'KBLS', 'QUINTET PRIVATE BANK (EUROPE) S.A. - STRUCTURED PRODUCTS', None, 543, 'Not Specified'),
#  ('LU', 'KBLT', 'QUINTET PRIVATE BANK (EUROPE) S.A. - FX TREASURY DERIVATIVES', None, 544, 'Not Specified'),
#  ('LU', 'KBLL', 'QUINTET PRIVATE BANK (EUROPE) S.A.', None, 545, 'Not Specified'),
#  ('FR', 'MHBP', 'MIZUHO BANK LTD. - PARIS BRANCH', None, 546, 'Not Specified'),
#  ('DE', 'MHEU', 'MIZUHO SECURITIES EUROPE', 'MHEU', 547, 'EUR'),
#  ('CZ', 'UBCZ', 'UNICREDIT BANK CZECH REPUBLIC AND SLOVAKIA, A.S.', None, 548, 'Not Specified'),
#  ('DE', 'XETS', 'XETRA - SCALE', None, 549, 'EUR'),
#  ('DE', 'FRAS', 'BOERSE FRANKFURT - SCALE', None, 550, 'EUR'),
#  ('CY', 'ATLN', 'ATONLINE LIMITED', None, 551, 'Not Specified'),
#  ('NL', 'CEUE', 'CBOE EUROPE - CXE ORDER BOOKS (NL)', 'CBOE EU CXE', 552, 'Not Specified'),
#  ('DE', 'LBCW', 'LLOYDS BANK CORPORATE MARKETS WERTPAPIERHANDELSBANK GMBH', None, 553, 'EUR'),
#  ('US', 'VALX', 'VIRTU CLIENT MARKET MAKING', 'VCMM', 554, 'USD'),
#  ('ES', 'AGBP', 'A AND G BANCA PRIVADA SAU', None, 555, 'Not Specified'),
#  ('CZ', 'CESI', 'CESKOSLOVENSKÁ OBCHODNÍ BANKA, A.S. - SYSTEMATIC INTERNALISER', 'CSOB', 556, 'Not Specified'),
#  ('NL', 'EBSN', 'EBS MTF', None, 557, 'Not Specified'),
#  ('NL', 'ECEU', 'TRADECHO EU APA', None, 558, 'Not Specified'),
#  ('FR', 'TPIO', 'TP ICAP EU - MTF - ORDERBOOK', None, 559, 'Not Specified'),
#  ('FR', 'TPIC', 'TP ICAP EU - MTF', None, 560, 'Not Specified'),
#  ('US', 'XTRD', 'XTRD', 'XTRD', 561, 'USD'),
#  ('FR', 'MLEX', 'BOFA SECURITIES EUROPE', 'BOFASE', 562, 'Not Specified'),
#  ('FR', 'MLER', 'BOFA SECURITIES EUROPE - RFQ', 'BOFASE', 563, 'Not Specified'),
#  ('FR', 'MLES', 'BOFA SECURITIES EUROPE - SYSTEMATIC INTERNALISER', 'BOFASE', 564, 'Not Specified'),
#  ('GB', 'MLIB', 'MERRILL LYNCH INTERNATIONAL BANK DESIGNATED ACTIVITY COMPANY', 'BAMLI DAC', 565, 'GBP'),
#  ('DK', 'DSME', 'FIRST NORTH DENMARK -SME GROWTH MARKET', None, 566, 'Not Specified'),
#  ('FI', 'FSME', 'FIRST NORTH FINLAND - SME GROWTH MARKET', None, 567, 'Not Specified'),
#  ('US', 'XNFI', 'NASDAQ FIXED INCOME TRADING', None, 568, 'USD'),
#  ('US', 'ESPD', 'NASDAQ OMX ESPEED', 'ESPEED', 569, 'USD'),
#  ('SE', 'SSME', 'FIRST NORTH SWEDEN - SME GROWTH MARKET', None, 570, 'Not Specified'),
#  ('CY', 'ATHL', 'ATHLOS CAPITAL INVESTMENT SERVICES LTD', None, 571, 'Not Specified'),
#  ('CY', 'BCSC', 'BROKERCREDITSERVICE (CYPRUS) LIMITED', 'BCE', 572, 'Not Specified'),
#  ('CY', 'CFIF', 'CREDIT FINANCIER INVEST (CFI) LTD', 'CFI', 573, 'Not Specified'),
#  ('DE', 'JESI', 'JEFFERIES EUROPE - SYSTEMATIC INTERNALISER', None, 574, 'EUR'),
#  ('DE', 'JEFE', 'JEFFERIES EUROPE', None, 575, 'EUR'),
#  ('GB', 'MHBL', 'MIZUHO BANK, LTD. LONDON BRANCH', None, 576, 'GBP'),
#  ('FR', 'NOWX', 'NOW CP - NEU CP', None, 577, 'Not Specified'),
#  ('PL', 'PKOP', 'BANK POLSKA KASA OPIEKI S.A.', 'PEKAO', 578, 'Not Specified'),
#  ('US', 'VCRS', 'VIRTU MATCHIT - CONDITIONAL ROOM', 'KCGM', 579, 'USD'),
#  ('US', 'VUSA', 'VIRTU AMERICAS LLC', 'VAL', 580, 'USD'),
#  ('US', 'VFMI', 'VIRTU MATCHIT - MAIN CROSSING SESSION', 'KCGM', 581, 'USD'),
#  ('ES', 'ABAN', 'ABANCA', None, 582, 'Not Specified'),
#  ('RO', 'BRDS', 'BRD - GROUPE SOCIETE GENERALE S.A. - SYSTEMATIC INTERNALISER', None, 583, 'Not Specified'),
#  ('IE', 'EQIE', 'EQUILEND LIMITED', None, 584, 'Not Specified'),
#  ('GB', 'EQLD', 'EQUILEND EUROPE LIMITED', None, 585, 'GBP'),
#  ('CY', 'GPBC', 'GPB-FINANCIAL SERVICES LTD', None, 586, 'Not Specified'),
#  ('RU', 'RTSX', 'MOSCOW EXCHANGE - DERIVATIVES MARKET', 'MOEX', 587, 'Not Specified'),
#  ('NL', 'OHVO', 'OHV OTF', None, 588, 'Not Specified'),
#  ('DE', 'RBCG', 'RBC CAPITAL MARKETS (EUROPE) GMBH', None, 589, 'EUR'),
#  ('IE', 'RMTF', 'REFINITIV MTF', None, 590, 'Not Specified'),
#  ('AT', 'UCBA', 'UNICREDIT BANK AUSTRIA AG', None, 591, 'Not Specified'),
#  ('DE', 'UCDE', 'UNICREDIT BANK AG', None, 592, 'EUR'),
#  ('IT', 'UCIT', 'UNICREDIT SPA', None, 593, 'Not Specified'),
#  ('GB', 'BRGA', 'BRYAN GARNIER AND CO LIMITED', None, 594, 'GBP'),
#  ('FI', 'XNOR', 'NORDEA', None, 595, 'Not Specified'),
#  ('NL', 'XNXD', 'NXCHANGE B.V. MTF', None, 596, 'Not Specified'),
#  ('ES', 'BCMA', 'BANCA MARCH S.A.', 'MARCH', 597, 'Not Specified'),
#  ('CZ', 'CSOB', 'CESKOSLOVENSKÁ OBCHODNÍ BANKA, A.S.', 'CSOB', 598, 'Not Specified'),
#  ('IE', 'ICXR', 'CURRENEX IRELAND MTF - RFQ', 'CNX MTF', 599, 'Not Specified'),
#  ('IE', 'ICUR', 'CURRENEX IRELAND MTF', 'CNX MTF', 600, 'Not Specified'),
#  ('IE', 'IFXC', 'FX CONNECT IRELAND MTF', 'IFXC MTF', 601, 'Not Specified'),
#  ('IE', 'IFXA', 'FX CONNECT IRELAND MTF - ALLOCATIONS', 'IFXC MTF', 602, 'Not Specified'),
#  ('IE', 'IFXR', 'FX CONNECT IRELAND MTF - RFQ', 'IFXC MTF', 603, 'Not Specified'),
#  ('NL', 'MUSN', 'MUFG SECURITIES (EUROPE) N.V -', None, 604, 'Not Specified'),
#  ('GB', 'SPDX', 'SPREADEX', None, 605, 'GBP'),
#  ('DE', 'MESI', 'MORGAN STANLEY EUROPE S.E. - SYSTEMATIC INTERNALISER', 'MESI', 606, 'EUR'),
#  ('NL', 'NIBC', 'NIBC', None, 607, 'Not Specified'),
#  ('UA', 'UICE', 'UKRAINIAN INTERBANK CURRENCY EXCHANGE', 'UICE', 608, 'Not Specified'),
#  ('UA', 'XNDU', 'PJSC NATIONAL DEPOSITORY OF UKRAINE', 'PJSC NDU', 609, 'Not Specified'),
#  ('SE', 'GBWB', 'NASDAQ STOCKHOLM AB - GBP WB EQ DERIVATIVES', None, 610, 'Not Specified'),
#  ('GB', 'ECSL', 'ENTERPRISE COMMODITY SERVICES LIMITED', None, 611, 'GBP'),
#  ('FR', 'MSCX', 'MORGAN STANLEY MTF - CONTINUOUS CROSS DARK', 'MSCX', 612, 'Not Specified'),
#  ('FR', 'MSAX', 'MORGAN STANLEY MTF - PERIODIC AUCTION', 'MSAX', 613, 'Not Specified'),
#  ('FR', 'MSNT', 'MORGAN STANLEY MTF - NEGOTIATED TRADE', 'MSNT', 614, 'Not Specified'),
#  ('DE', 'MSEU', 'MORGAN STANLEY EUROPE S.E.', 'MSEU', 615, 'EUR'),
#  ('GB', 'TPIS', 'TULLETT PREBON - INSTITUTIONAL SERVICES - OTF', None, 616, 'GBP'),
#  ('RO', 'BRDL', 'BRD - GROUPE SOCIETE GENERALE S.A. - LIQUIDITY PROVIDER', None, 617, 'Not Specified'),
#  ('RO', 'BRDE', 'BRD - GROUPE SOCIETE GENERALE S.A.', None, 618, 'Not Specified'),
#  ('GB', 'CIBC', 'CANADIAN IMPERIAL BANK OF COMMERCE', 'CIBC', 619, 'GBP'),
#  ('GB', 'CIBP', 'CIBC WORLD MARKETS PLC', 'CIBC WM PLC', 620, 'GBP'),
#  ('CZ', 'FTFM', '42 FINANCIAL SERVICES - MTF', '42FS', 621, 'Not Specified'),
#  ('CZ', 'FTFS', '42 FINANCIAL SERVICES', '42FS', 622, 'Not Specified'),
#  ('ES', 'CABK', 'CAIXABANK', 'CABK', 623, 'Not Specified'),
#  ('NL', 'BARU', 'CBOE EUROPE - REGULATED MARKET DARK BOOK (NL)', 'CBOE EU REGM DARK', 624, 'Not Specified'),
#  ('NL', 'BEUO', 'CBOE EUROPE - REGULATED MARKET OFF BOOK (NL)', 'CBOE EU REGM OFF BOOK', 625, 'Not Specified'),
#  ('NL', 'BEUT', 'CBOE EUROPE - REGULATED MARKET INTEGRATED BOOK (NL)', 'CBOE EU REGM LIT', 626, 'Not Specified'),
#  ('NL', 'CCRM', 'CBOE EUROPE REGULATED MARKETS (NL)', 'CBOE EU RM', 627, 'Not Specified'),
#  ('NL', 'CAPA', 'CBOE EUROPE - APA (NL)', 'CBOE EU OFF EXCHANGE', 628, 'Not Specified'),
#  ('NL', 'LISZ', 'CBOE EUROPE - LIS SERVICE (NL)', 'CBOE EU LIS', 629, 'Not Specified'),
#  ('NL', 'CCXE', 'CBOE EUROPE EQUITIES - EUROPEAN EQUITIES (NL)', 'CBOE EUROPE B.V.', 630, 'Not Specified'),
#  ('DE', 'DEKA', 'DEKABANK DEUTSCHE GIROZENTRALE', None, 631, 'EUR'),
#  ('US', 'IATS', 'IBKR ATS', 'IATS', 632, 'USD'),
#  ('FR', 'ICOT', 'ICAP EU - OTF', None, 633, 'Not Specified'),
#  ('GB', 'IPXP', 'IPSX PRIME', 'IPSX', 634, 'GBP'),
#  ('GB', 'ISSI', 'ICBC STANDARD BANK', 'ICBCS', 635, 'GBP'),
#  ('DK', 'JYSI', 'DEN JYSKE SPAREKASSE', None, 636, 'Not Specified'),
#  ('NL', 'NWNV', 'NATWEST MARKETS NV', 'NWM NV', 637, 'Not Specified'),
#  ('HU', 'OTPB', 'OTP BANK NYRT', None, 638, 'Not Specified'),
#  ('HU', 'RBHU', 'RAIFFEISEN BANK (HUNGARY)', 'RBHU-SI', 639, 'Not Specified'),
#  ('CY', 'RENC', 'RENAISSANCE SECURITIES (CYPRUS) LIMITED', None, 640, 'Not Specified'),
#  ('FR', 'TPEU', 'TULLETT PREBON EU OTF', None, 641, 'Not Specified'),
#  ('GB', 'WSIL', 'WELLS FARGO SECURITIES INTERNATIONAL', None, 642, 'GBP'),
#  ('PL', 'INGW', 'ING BANK SLASKI SA', None, 643, 'Not Specified'),
#  ('GB', 'MAKX', 'MAKOR SECURITIES LONDON LTD', None, 644, 'GBP'),
#  ('GB', 'WSIN', 'WESTPAC BANKING CORPORATION', 'WBC SI', 645, 'GBP'),
#  ('DE', 'BGFX', 'BERENBERG FX', 'BGFX', 646, 'EUR'),
#  ('DE', 'BGFI', 'BERENBERG FIXED INCOME', 'BGFI', 647, 'EUR'),
#  ('AT', 'SLHB', 'SALZBURGER LANDES-HYPOTHEKENBANK', None, 648, 'Not Specified'),
#  ('CY', 'SIBC', 'SIB CYPRUS LTD', 'SIB', 649, 'Not Specified'),
#  ('GB', 'WELN', 'WEL', 'WEL SI', 650, 'GBP'),
#  ('GB', 'BMLB', 'BANK OF MONTREAL - LONDON BRANCH', 'BMO', 651, 'GBP'),
#  ('US', 'WELX', 'WELLS FARGO LIQUIDITY CROSS ATS', None, 652, 'USD'),
#  ('SE', 'XSAT', 'SPOTLIGHT STOCK MARKET AB', None, 653, 'Not Specified'),
#  ('HK', 'BAIP', 'BANK OF AMERICA MERRILL LYNCH EQUITY SWAP - INTERNAL PRICE SOURCE', None, 654, 'Not Specified'),
#  ('HK', 'BAEP', 'BANK OF AMERICA MERRILL LYNCH EQUITY SWAP - EXTERNAL PRICE SOURCE', None, 655, 'Not Specified'),
#  ('IE', 'DAVY', 'J AND E DAVY - IRISH GOVERNMENT BOND', None, 656, 'Not Specified'),
# ...
#  ('IE', 'SISI', 'SUSQUEHANNA INTERNATIONAL SECURITIES LIMITED', 'SISI', 772, 'Not Specified'),
#  ('IT', 'BEIS', 'BANCA ETICA', None, 773, 'Not Specified'),
#  ('DE', 'BLBB', 'BAYERNLB', None, 774, 'EUR'),
#  ('JP', 'BASX', 'BANK OF AMERICA MERRILL LYNCH - SIMPLEX BLAST X', None, 775, 'Not Specified'),
#  ('US', 'HRTX', 'HUDSON RIVER TRADING', 'HRT', 776, 'USD'),
#  ('NO', 'ICAS', 'ICAP ENERGY AS', None, 777, 'Not Specified'),
#  ('US', 'INCR', 'INTELLIGENTCROSS', None, 778, 'USD'),
#  ('GB', 'IOFB', 'ICAP SECURITIES OTF - BUTLER FX DERIVATIVES', None, 779, 'GBP'),
#  ('US', 'MSRP', 'MS RPOOL', None, 780, 'USD'),
#  ('GB', 'OCSI', 'SOVA CAPITAL', None, 781, 'GBP'),
#  ('FR', 'EDRF', 'EDMOND DE ROTHSCHILD  (FRANCE)', None, 782, 'Not Specified'),
#  ('CA', 'BNSX', 'THE BANK OF NOVA SCOTIA', None, 783, 'Not Specified'),
#  ('FR', 'EXSE', 'EXANE BNP PARIBAS - SYSTEMATIC INTERNALISER', 'EXSE', 784, 'Not Specified'),
#  ('GB', 'MSSI', 'MORGAN STANLEY AND CO. INTERNATIONAL PLC - SYSTEMATIC INTERNALISER', None, 785, 'GBP'),
#  ('GB', 'TPLF', 'TULLETT PREBON - INSTITUTIONAL SERVICES - LIQUIDITY CHAIN - OTF - CORPORATE BONDS AND SECURITISED DEBT', None, 786, 'GBP'),
#  ('US', 'MELO', 'NASDAQ MIDPOINT-ELO (M-ELO)', 'MELO', 787, 'USD'),
#  ('KZ', 'AIXK', 'ASTANA INTERNATIONAL EXCHANGE LTD', 'AIX', 788, 'Not Specified'),
#  ('US', 'CBLC', 'CITIBLOC', 'CBLC', 789, 'USD'),
#  ('US', 'CIOI', 'CIOI', 'CIOI', 790, 'USD'),
#  ('GB', 'LBCM', 'LLOYDS BANK CORPORATE MARKETS', 'LBCM', 791, 'GBP'),
#  ('AT', 'RLBO', 'RAIFFEISENLANDESBANK OBERÖSTERREICH', None, 792, 'Not Specified'),
#  ('GB', 'SBEX', 'SCOTIABANK', None, 793, 'GBP'),
#  ('GB', 'VTBC', 'VTB CAPITAL PLC', None, 794, 'GBP'),
#  ('DE', 'XEHQ', 'EUREX REPO - HQLA MARKET', None, 795, 'EUR'),
#  ('ZA', 'ZARX', 'ZAR X', 'ZARX', 796, 'Not Specified'),
#  ('GB', 'IPSX', 'IPSX', 'IPSX', 797, 'GBP'),
#  ('DE', 'TPDE', 'TULLETT PREBON SECURITIES - FRANKFURT - OTF', None, 798, 'EUR'),
#  ('DE', 'TSFG', 'TULLETT PREBON SECURITIES - FRANKFURT - OTF - GOVERNMENT BONDS - EX GILTS', None, 799, 'EUR'),
#  ('DE', 'TSFF', 'TULLETT PREBON SECURITIES - FRANKFURT - OTF - CORPORATE BONDS AND SECURITISED DEBT', None, 800, 'EUR'),
#  ('NL', 'COMM', 'COMMERG', None, 801, 'Not Specified'),
#  ('SE', 'MOSE', 'FIRST NORTH SWEDEN - NORWAY AUCTION ON DEMAND', None, 802, 'Not Specified'),
#  ('SE', 'DOSE', 'FIRST NORTH SWEDEN - NORWAY NORDIC@MID', None, 803, 'Not Specified'),
#  ('GB', 'ATLB', 'BRAEMAR ATLANTIC SECURITIES LTD', None, 804, 'GBP'),
#  ('CH', 'CCMS', 'CONTINENTAL CAPITAL MARKETS S.A.', None, 805, 'Not Specified'),
#  ('GB', 'DAIW', 'DAIWA CAPITAL MARKETS EUROPE LIMITED', None, 806, 'GBP'),
#  ('IT', 'IBEQ', 'INVEST BANCA - IBIS EQUITY', None, 807, 'Not Specified'),
#  ('IN', 'IINX', 'INDIA INTERNATIONAL EXCHANGE (IFSC) LIMITED', 'INDIA INX', 808, 'Not Specified'),
#  ('US', 'EMLD', 'MIAX EMERALD, LLC', 'EMLD', 809, 'USD'),
#  ('FI', 'OPCO', 'OP CORPORATE BANK PLC', 'OP', 810, 'Not Specified'),
#  ('US', 'TSBX', 'DBOT ATS, LLC', 'DBOT', 811, 'USD'),
#  ('CA', 'TMXS', 'TMX SELECT', None, 812, 'Not Specified'),
#  ('BE', 'BELF', 'BELFIUS BANK NV/SA FIXED INCOME', None, 813, 'Not Specified'),
#  ('BE', 'BELB', 'BELFIUS BANK NV/SA', None, 814, 'Not Specified'),
#  ('GB', 'IMTF', 'INTEGRAL MTF', None, 815, 'GBP'),
#  ('US', 'MAGM', 'MAGMA ATS', None, 816, 'USD'),
#  ('AU', 'ASXC', 'ASX - CENTRE POINT', 'ASX', 817, 'Not Specified'),
#  ('CN', 'CFBC', 'CHINA FOREIGN EXCHANGE TRADE SYSTEM - SHANGHAI - HONG KONG BOND CONNECT', 'CFETSBC', 818, 'Not Specified'),
#  ('AU', 'BLXA', 'INSTINET BLX (AU)', None, 819, 'Not Specified'),
#  ('SE', 'GFKS', 'GARANTUM FONDKOMMISSION AB', None, 820, 'Not Specified'),
#  ('FR', 'SGOE', 'SG OPTION EUROPE', 'SGOE SI', 821, 'Not Specified'),
#  ('US', 'UBSA', 'UBS ATS', 'UBS ATS', 822, 'USD'),
#  ('US', 'UBSS', 'UBS SECURITIES LLC', None, 823, 'USD'),
#  ('IT', 'IBIS', 'INVEST BANCA', None, 824, 'Not Specified'),
#  ('US', 'PDQD', 'CODA MARKETS ATS DARK', None, 825, 'USD'),
#  ('HK', 'TFSD', 'T.F.S. DERIVATIVES HK LIMITED', None, 826, 'Not Specified'),
#  ('HK', 'TRAS', 'TRADITION ASIA LIMITED', None, 827, 'Not Specified'),
#  ('SG', 'TSIG', 'TRADITION SINGAPORE PTE. LTD.', None, 828, 'Not Specified'),
#  ('JP', 'UTSL', 'UEDA TRADITION SECURITIES LTD.', None, 829, 'Not Specified'),
#  ('RO', 'SBMF', 'SPOT REGULATED MARKET - BMFMS', None, 830, 'Not Specified'),
#  ('RO', 'BMFM', 'DERIVATIVES REGULATED MARKET - BMFMS', 'BMFMS', 831, 'Not Specified'),
#  ('RO', 'BMFA', 'BMFMS-ATS', None, 832, 'Not Specified'),
#  ('RO', 'BMFX', 'SIBIU MONETARY- FINANCIAL AND COMMODITIES EXCHANGE', None, 833, 'Not Specified'),
#  ('CH', 'CSZH', 'CREDIT SUISSE (CH)', 'CSZ', 834, 'Not Specified'),
#  ('GB', 'STAL', 'SCHNEIDER OTF', None, 835, 'GBP'),
#  ('JP', 'JASR', 'JAPANCROSSING', None, 836, 'Not Specified'),
#  ('JP', 'XIJP', 'INSTINET JAPAN', None, 837, 'Not Specified'),
#  ('ES', 'XMCE', 'MERCADO CONTINUO ESPANOL - CONTINUOUS MARKET', 'SIBE', 838, 'Not Specified'),
#  ('DE', 'EUWA', 'EUWAX AG', None, 839, 'EUR'),
#  ('FR', 'EXSY', 'EXANE DERIVATIVES', None, 840, 'Not Specified'),
#  ('ZA', 'A2XX', 'A2X', 'A2X', 841, 'Not Specified'),
#  ('GB', 'FXOP', 'TRADITION-NEX OTF', None, 842, 'GBP'),
#  ('IT', 'BOND', 'BONDVISION ITALIA', None, 843, 'Not Specified'),
#  ('GB', 'TFSG', 'TRADITION ENERGY', None, 844, 'GBP'),
#  ('GB', 'TCDS', 'TRADITION OTF', None, 845, 'GBP'),
#  ('GB', 'TRDE', 'TRADITION', None, 846, 'GBP'),
#  ('GB', 'NAVE', 'NAVESIS-MTF', None, 847, 'GBP'),
#  ('HR', 'ZAPA', 'ZAGREB STOCK EXCHANGE - APA', None, 848, 'Not Specified'),
#  ('IT', 'AKIS', 'AKIS - BANCA AKROS', 'AKIS', 849, 'Not Specified'),
#  ('FR', 'BPSX', 'BNP PARIBAS SECURITIES SERVICES', 'BP2S', 850, 'Not Specified'),
#  ('GB', 'ISWE', 'ICAP GLOBAL DERIVATIVES LIMITED - ELECTRONIC', None, 851, 'GBP'),
#  ('GB', 'ISWV', 'ICAP GLOBAL DERIVATIVES LIMITED - VOICE', None, 852, 'GBP'),
#  ('GB', 'IGDL', 'ICAP GLOBAL DERIVATIVES LIMITED', None, 853, 'GBP'),
#  ('FR', 'HPCV', 'HPC SA - VOICE OTF', 'HPC', 854, 'Not Specified'),
#  ('GB', 'JSSI', 'JANE STREET FINANCIAL LTD', 'JSF', 855, 'GBP'),
#  ('SE', 'SEBX', 'SEB - LIQUIDITY POOL', 'SEB', 856, 'Not Specified'),
#  ('GB', 'TWGP', 'TRADEWEB EUROPE LIMITED - GLOBAL TRADING PLATFORM', None, 857, 'GBP'),
#  ('AE', 'GMGD', 'GMG DUBAI LIMITED', 'GMGDXB', 858, 'Not Specified'),
#  ('GB', 'GMGL', 'GMG BROKERS LIMITED', 'GMGLDN', 859, 'GBP'),
#  ('NL', 'NPEX', 'NPEX', None, 860, 'Not Specified'),
#  ('NO', 'OAPA', 'OSLO BORS - APA', None, 861, 'Not Specified'),
#  ('IT', 'DDTX', 'DEAL DONE TRADING', 'DDT', 862, 'Not Specified'),
#  ('FR', 'HPCX', 'HPC SA', None, 863, 'Not Specified'),
#  ('NO', 'SB1M', 'SPAREBANK 1 MARKETS', 'SB1M', 864, 'Not Specified'),
#  ('GB', 'SEDR', 'SEEDRS - SECONDARY MARKET', None, 865, 'GBP'),
#  ('GB', 'ANTS', 'ABBEY NATIONAL TREASURY SERVICES PLC', 'ANTS', 866, 'GBP'),
#  ('PL', 'IENG', 'INFOENGINE OTC', None, 867, 'Not Specified'),
#  ('GB', 'SGMY', 'SIGMA X MTF - AUCTION BOOK', None, 868, 'GBP'),
#  ('GB', 'SGMX', 'SIGMA X MTF', None, 869, 'GBP'),
#  ('DE', 'SSBM', 'STATE STREET BANK INTERNATIONAL FX', 'SSBI', 870, 'EUR'),
#  ('DE', 'SSBI', 'STATE STREET BANK INTERNATIONAL GMBH', 'SSBI', 871, 'EUR'),
#  ('DE', 'DBES', 'DEUTSCHE BANK AG - SYSTEMATIC INTERNALISER', 'DBES', 872, 'EUR'),
#  ('DE', 'DBAG', 'DEUTSCHE BANK AG', None, 873, 'EUR'),
#  ('CY', 'MKAP', 'MERITKAPITAL', None, 874, 'Not Specified'),
#  ('HK', 'GSAL', 'GOLDMAN SACHS (ASIA) LLC', None, 875, 'Not Specified'),
#  ('HK', 'GSXH', 'GSX HONG KONG', None, 876, 'Not Specified'),
#  ('HK', 'SIGH', 'SIGMA X HONG KONG', 'GSET', 877, 'Not Specified'),
#  ('EE', 'SWEE', 'SWEDBANK ESTONIA', None, 878, 'Not Specified'),
#  ('LT', 'SWLT', 'SWEDBANK LITHUANIA', None, 879, 'Not Specified'),
#  ('LV', 'SWLV', 'SWEDBANK LATVIA', None, 880, 'Not Specified'),
#  ('GB', 'TECO', 'TULLETT PREBON EUROPE - OTF - COMMODITY AND ENERGY DERIVATIVES', None, 881, 'GBP'),
#  ('HR', 'XZAP', 'PROGRESS MARKET', None, 882, 'Not Specified'),
#  ('FR', 'ODDO', 'ODDO BHF', None, 883, 'Not Specified'),
#  ('FR', 'ODOC', 'ODDO CONTREPARTIE', None, 884, 'Not Specified'),
#  ('US', 'PULX', 'INSTINET BLOCKCROSS ATS', 'BLKX', 885, 'USD'),
#  ('ES', 'SANT', 'BANCO SANTANDER S.A.', 'SANT', 886, 'Not Specified'),
#  ('GB', 'UBIN', 'UNION BANK OF INDIA UK LTD', None, 887, 'GBP'),
#  ('GB', 'CSLB', 'CREDIT SUISSE AG - LONDON BRANCH', 'CSAGLB SI', 888, 'GBP'),
#  ('GB', 'JISI', 'JEFFERIES INTERNATIONAL', None, 889, 'GBP'),
#  ('GB', 'JEFS', 'JEFFERIES INTERNATIONAL - SYSTEMATIC INTERNALISER', None, 890, 'GBP'),
#  ('DE', 'VTPS', 'TRADEPLUS', None, 891, 'EUR'),
#  ('DE', 'VWDX', 'VWD TRANSACTIONSOLUTIONS AG', None, 892, 'EUR'),
#  ('DE', 'VTLS', 'TRADELINK', None, 893, 'EUR'),
#  ('US', 'BAMX', 'BANK OF AMERICA - MERRILL LYNCH GCX', 'MLCX', 894, 'USD'),
#  ('NL', 'IMCO', 'ICE ENDEX OTF FUTURES', 'ICE ENDEX OTF', 895, 'Not Specified'),
#  ('SE', 'ENSX', 'SEB ENSKILDA', None, 896, 'Not Specified'),
#  ('SE', 'SEBS', 'SEB', 'SEB', 897, 'Not Specified'),
#  ('US', 'INCA', 'INSTINET DESK CROSS', None, 898, 'USD'),
#  ('IT', 'SSOB', 'BONDVISION EUROPE MTF', None, 899, 'Not Specified'),
#  ('SE', 'XABC', 'ABG SUNDAL COLLIER AB', None, 900, 'Not Specified'),
#  ('GB', 'GFIC', 'GFI SECURITIES LTD', None, 901, 'GBP'),
#  ('HU', 'KELR', 'KELER', None, 902, 'Not Specified'),
#  ('GB', 'MLXN', 'BANK OF AMERICA - MERRILL LYNCH INSTINCT X - EUROPE', None, 903, 'GBP'),
#  ('GB', 'MLAX', 'BANK OF AMERICA - MERRILL LYNCH AUCTION CROSS', None, 904, 'GBP'),
#  ('US', 'XBOX', 'BOX OPTIONS EXCHANGE', 'BOX', 905, 'USD'),
#  ('DE', 'NORD', 'HSH NORDBANK', None, 906, 'EUR'),
#  ('CH', 'OTXB', 'BERNER KANTONALBANK OTC-X', 'OTC-X', 907, 'Not Specified'),
#  ('IE', 'SEMX', 'SEMOPX', None, 908, 'Not Specified'),
#  ('FR', 'XAPA', 'EURONEXT - APA', None, 909, 'Not Specified'),
#  ('FR', 'AACA', 'CREDIT AGRICOLE CIB', 'CACIB SI', 910, 'Not Specified'),
#  ('DK', 'ABSI', 'ALM. BRAND BANK', None, 911, 'Not Specified'),
#  ('DE', 'BINV', 'BOND INVEST', None, 912, 'EUR'),
#  ('US', 'GLMX', 'GLMX', None, 913, 'USD'),
#  ('BM', 'GTXE', 'GTX ECN', None, 914, 'Not Specified'),
#  ('GB', 'JPCB', 'JPMORGAN CHASE BANK N.A. LONDON BRANCH', None, 915, 'GBP'),
#  ('GB', 'REST', 'NEX SEF MTF - RESET - RISK MITIGATION SERVICES', 'NSL', 916, 'GBP'),
#  ('DE', 'NLBX', 'NORDDEUTSCHE LANDESBANK - GIROZENTRALE', None, 917, 'EUR'),
#  ('CH', 'XREP', 'SIX REPO AG - CH REPO MARKET', 'SIX', 918, 'Not Specified'),
#  ('CH', 'ROSR', 'SIX REPO AG', 'SIX', 919, 'Not Specified'),
#  ('CH', 'XROT', 'SIX REPO AG - OTC SPOT MARKET', 'SIX', 920, 'Not Specified'),
#  ('LI', 'XLLB', 'LIECHTENSTEINISCHE LANDESBANK AG', None, 921, 'Not Specified'),
#  ('LI', 'XVPB', 'VP BANK AG', None, 922, 'Not Specified'),
#  ('PL', 'HBPL', 'HSBC BANK POLSKA S.A.', None, 923, 'Not Specified'),
#  ('GB', 'LMAO', 'LMAX - INDICES/RATES/COMMODITIES', None, 924, 'GBP'),
#  ('GB', 'LMAE', 'LMAX - EQUITIES', None, 925, 'GBP'),
#  ('GB', 'LMAF', 'LMAX - FX', None, 926, 'GBP'),
#  ('NO', 'XABG', 'ABG SUNDAL COLLIER ASA', 'ABG', 927, 'Not Specified'),
#  ('DK', 'ALSI', 'AKTIESELSKABET ARBEJDERNES LANDSBANK', 'ALSI', 928, 'Not Specified'),
#  ('SG', 'APCL', 'ASIA PACIFIC CLEAR', 'APEX CLEAR', 929, 'Not Specified'),
#  ('DK', 'SBSI', 'SYDBANK A/S', None, 930, 'Not Specified'),
#  ('GB', 'TDBL', 'TORONTO DOMINION BANK - LONDON BRANCH', 'TD BANK', 931, 'GBP'),
#  ('FR', 'BNPA', 'BNP PARIBAS ARBITRAGE SNC', 'BNPP A SI', 932, 'Not Specified'),
#  ('BE', 'BNPF', 'BNP PARIBAS FORTIS SA/NV', 'BNPPF SI', 933, 'Not Specified'),
#  ('FR', 'BNPS', 'BNP PARIBAS SA', 'BNPP SA SI', 934, 'Not Specified'),
#  ('IT', 'SEDX', 'SECURITISED DERIVATIVES MARKET', 'SEDEX', 935, 'Not Specified'),
#  ('GB', 'CMED', 'CME EUROPE - DERIVATIVES', 'CME', 936, 'GBP'),
#  ('GB', 'ICEO', 'ICAP ENERGY - OTF', None, 937, 'GBP'),
#  ('GB', 'IECL', 'ICAP ENERGY LTD OTF - COMMODITIES AND ENERGY DERIVATIVES', None, 938, 'GBP'),
#  ('GB', 'IOFI', 'ICAP UK OTF - CORPORATE BONDS AND SECURITISED DEBT', None, 939, 'GBP'),
#  ('GB', 'IOFX', 'ICAP UK OTF - FX DERIVATIVES', None, 940, 'GBP'),
#  ('GB', 'IOGB', 'ICAP UK OTF - GOVERNMENT BONDS EXCLUDING  UK GILTS', None, 941, 'GBP'),
#  ('GB', 'IOCD', 'ICAP UK OTF - CREDIT DERIVATIVES', None, 942, 'GBP'),
#  ('GB', 'IOED', 'ICAP UK OTF - EQUITY DERIVATIVES', None, 943, 'GBP'),
#  ('GB', 'IOGI', 'ICAP UK OTF - GOVERNMENT BONDS - UK GILTS', None, 944, 'GBP'),
#  ('GB', 'IOIR', 'ICAP UK OTF - INTEREST RATE DERIVATIVES', None, 945, 'GBP'),
#  ('GB', 'IOMM', 'ICAP UK OTF - MONEY MARKET INSTRUMENTS', None, 946, 'GBP'),
#  ('GB', 'ISWA', 'ISWAP UK MTF', None, 947, 'GBP'),
#  ('ES', 'MDRV', 'MIBGAS - DERIVATIVES', 'MIBGAS', 948, 'Not Specified'),
#  ('GB', 'NWMS', 'ROYAL BANK OF SCOTLAND', 'RBS PLC', 949, 'GBP'),
#  ('GB', 'RBCE', 'RBC EUROPE LIMITED', None, 950, 'GBP'),
#  ('US', 'IIDX', 'INSTINET IDX', None, 951, 'USD'),
#  ('US', 'IBLX', 'INSTINET BLX', None, 952, 'USD'),
#  ('US', 'RCBX', 'INSTINET RETAIL CBX', 'RCBX', 953, 'USD'),
#  ('MT', 'IFSM', 'INSTITUTIONAL FINANCIAL SECURITIES MARKET', 'IFSM', 954, 'Not Specified'),
#  ('GB', 'MTSS', 'MTS INTERDEALER SWAPS MARKET', None, 955, 'GBP'),
#  ('GB', 'MTSW', 'MTS SWAP MARKET', 'STF', 956, 'GBP'),
#  ('FR', 'XSGA', 'SOCIETE GENERALE', 'SG SI', 957, 'Not Specified'),
#  ('GB', 'ANLP', 'AUSTRALIA AND NEW ZEALAND BANKING GROUP LIMITED', None, 958, 'GBP'),
#  ('GB', 'KBLM', 'KYTE BROKING LIMITED', None, 959, 'GBP'),
#  ('FR', 'KOTF', 'OTFLINK', None, 960, 'Not Specified'),
#  ('DK', 'LASP', 'LAN AND SPAR BANK A/S', None, 961, 'Not Specified'),
#  ('AU', 'MACB', 'MACQUARIE AUSTRALIA BLOCK CROSSING', None, 962, 'Not Specified'),
#  ('FR', 'TDON', 'TRADITION PARIS - TSAF', 'TSAF', 963, 'Not Specified'),
#  ('FR', 'TSAF', 'TSAF OTC - OTF', 'TSAF OTC', 964, 'Not Specified'),
#  ('IT', 'UBIS', 'UNIPOL BANCA S.P.A.', 'UBIS', 965, 'Not Specified'),
#  ('GB', 'BRFQ', 'BLOCKMATCH UK RFQ', None, 966, 'GBP'),
#  ('GB', 'BNTW', 'BLOCKMATCH UK NT', None, 967, 'GBP'),
#  ('GB', 'BLOX', 'BLOCKMATCH  UK DARK', None, 968, 'GBP'),
#  ('GB', 'IOTC', 'INSTINET EUROPE LIMITED OTC', None, 969, 'GBP'),
#  ('GB', 'XIEL', 'INSTINET EUROPE LIMITED', None, 970, 'GBP'),
#  ('NO', 'XOAA', 'OSLO BORS ASA - OSLO AXESS LIT X AUCTIONS', None, 971, 'Not Specified'),
#  ('GB', 'BASI', 'BANK OF AMERICA, NATIONAL ASSOCIATION - LONDON BRANCH OFFICE - SYSTEMATIC INTERNALISER', 'BANA LONDON', 972, 'GBP'),
#  ('GB', 'BANA', 'BANK OF AMERICA, NATIONAL ASSOCIATION', 'BANA', 973, 'GBP'),
#  ('GB', 'BOAL', 'BANK OF AMERICA, NATIONAL ASSOCIATION - LONDON BRANCH OFFICE', None, 974, 'GBP'),
#  ('GB', 'CSEC', 'CITADEL SECURITIES FI', None, 975, 'GBP'),
#  ('GB', 'MLSI', 'MERRILL LYNCH INTERNATIONAL - SYSTEMATIC INTERNALISER', 'MLI', 976, 'GBP'),
#  ('GB', 'MLIX', 'MERRILL LYNCH INTERNATIONAL', 'MLI', 977, 'GBP'),
#  ('GB', 'MLRQ', 'MERRILL LYNCH INTERNATIONAL - RFQ', 'MLI', 978, 'GBP'),
#  ('SE', 'SVEX', 'SVENSKA HANDELSBANKEN AB - SVEX', 'SVEX', 979, 'Not Specified'),
#  ('SE', 'SVES', 'SVENSKA HANDELSBANKEN AB', 'SVEX', 980, 'Not Specified'),
#  ('GR', 'AAPA', 'ATHENS EXCHANGE - APA', 'ATHEX APA', 981, 'Not Specified'),
#  ('ES', 'CIMV', 'CIMD S.V. S.A. - OTF FOR DERIVATIVES', None, 982, 'Not Specified'),
#  ('ES', 'CIMB', 'CIMD S.V. S.A. - OTF FOR BONDS', None, 983, 'Not Specified'),
#  ('ES', 'CIME', 'CIMD S.V. S.A. - OTF FOR ENERGY DERIVATIVES', None, 984, 'Not Specified'),
#  ('ES', 'CIMD', 'CIMD S.V. S.A. - OTF', None, 985, 'Not Specified'),
#  ('US', 'CURX', 'CUREX FX', None, 986, 'USD'),
#  ('NL', 'INGE', 'ING BANK NV - SPRINTERS AND EQUITY', None, 987, 'Not Specified'),
#  ('NL', 'INGF', 'ING BANK NV - FOREIGN EXCHANGE', None, 988, 'Not Specified'),
#  ('DK', 'SKSI', 'SPAREKASSEN KRONJYLLAND', None, 989, 'Not Specified'),
#  ('GB', 'SQUA', 'SQUARE GLOBAL - OTF', None, 990, 'GBP'),
#  ('GB', 'SSBT', 'STATE STREET BANK AND TRUST COMPANY', 'SSBTCO', 991, 'GBP'),
#  ('GB', 'SSFX', 'STATE STREET BANK AND TRUST FX', 'SSBTCO', 992, 'GBP'),
#  ('NL', 'AFSO', 'AFS - OTF - BONDS', None, 993, 'Not Specified'),
#  ('NL', 'AFSX', 'AFS - OTF - FX FORWARDS', None, 994, 'Not Specified'),
#  ('NL', 'AFSL', 'AFS - OTF - STRUCTURED PRODUCTS', None, 995, 'Not Specified'),
#  ('NL', 'AFSA', 'AFS - OTF', None, 996, 'Not Specified'),
#  ('NL', 'AFSI', 'AFS - OTF - INTEREST RATE DERIVATIVES', None, 997, 'Not Specified'),
#  ('GB', 'ARIA', 'ARIAN TRADING FACILITY', None, 998, 'GBP'),
#  ('GB', 'DVFX', 'DIGITAL VEGA', 'DVFX', 999, 'GBP'),
#  ...]

# %%
# scrape wiki table with symbols and details of Dow Jones constituents
dj_constituents = pd.read_html('https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average#Components')[1]
dj_constituents.rename(columns={'Company':'name', 'Industry': 'industry', 'Symbol': 'ticker'}, inplace=True)
dj_constituents.head(30)
# Out:
#                         name Exchange ticker                        industry  \
# 0                         3M     NYSE    MMM                    Conglomerate
# 1           American Express     NYSE    AXP              Financial services
# 2                      Amgen   NASDAQ   AMGN               Biopharmaceutical
# 3                      Apple   NASDAQ   AAPL          Information technology
# 4                     Boeing     NYSE     BA           Aerospace and defense
# 5                Caterpillar     NYSE    CAT         Construction and Mining
# 6                    Chevron     NYSE    CVX              Petroleum industry
# 7                      Cisco   NASDAQ   CSCO          Information technology
# 8                  Coca-Cola     NYSE     KO                  Drink industry
# 9                     Disney     NYSE    DIS  Broadcasting and entertainment
# 10                       Dow     NYSE    DOW               Chemical industry
# 11             Goldman Sachs     NYSE     GS              Financial services
# 12                Home Depot     NYSE     HD                Home Improvement
# 13                 Honeywell   NASDAQ    HON                    Conglomerate
# 14                       IBM     NYSE    IBM          Information technology
# 15                     Intel   NASDAQ   INTC          Semiconductor industry
# 16         Johnson & Johnson     NYSE    JNJ         Pharmaceutical industry
# 17            JPMorgan Chase     NYSE    JPM              Financial services
# 18                McDonald's     NYSE    MCD                   Food industry
# 19                     Merck     NYSE    MRK         Pharmaceutical industry
# 20                 Microsoft   NASDAQ   MSFT          Information technology
# 21                      Nike     NYSE    NKE               Clothing industry
# 22          Procter & Gamble     NYSE     PG      Fast-moving consumer goods
# 23                Salesforce     NYSE    CRM          Information technology
# 24                 Travelers     NYSE    TRV                       Insurance
# 25              UnitedHealth     NYSE    UNH             Managed health care
# 26                   Verizon     NYSE     VZ     Telecommunications industry
# 27                      Visa     NYSE      V              Financial services
# 28  Walgreens Boots Alliance   NASDAQ    WBA                       Retailing
# 29                   Walmart     NYSE    WMT                       Retailing
#
#     Date added                                              Notes  \
# 0   1976-08-09              As Minnesota Mining and Manufacturing
# 1   1982-08-30                                                NaN
# 2   2020-08-31                                                NaN
# 3   2015-03-19                                                NaN
# 4   1987-03-12                                                NaN
# 5   1991-05-06                                                NaN
# 6   2008-02-19                      Also 1930-07-18 to 1999-11-01
# 7   2009-06-08                                                NaN
# 8   1987-03-12                      Also 1932-05-26 to 1935-11-20
# 9   1991-05-06                                                NaN
# 10  2019-04-02                                                NaN
# 11  2013-09-20                                                NaN
# 12  1999-11-01                                                NaN
# 13  2020-08-31  Also 1925-12-07 to 2008-02-19 under various na...
# 14  1979-06-29                      Also 1932-05-26 to 1939-03-04
# 15  1999-11-01                                                NaN
# 16  1997-03-17                                                NaN
# 17  1991-05-06                                                NaN
# 18  1985-10-30                                                NaN
# 19  1979-06-29                                                NaN
# 20  1999-11-01                                                NaN
# 21  2013-09-20                                                NaN
# 22  1932-05-26                                                NaN
# 23  2020-08-31                                                NaN
# 24  2009-06-08                                                NaN
# 25  2012-09-24                                                NaN
# 26  2004-04-08                                                NaN
# 27  2013-09-20                                                NaN
# 28  2018-06-26                                                NaN
# 29  1997-03-17                                                NaN
#
#    Index weighting
# 0            2.88%
# 1            3.56%
# 2            4.88%
# 3            3.15%
# 4            3.40%
# 5            4.19%
# 6            3.05%
# 7            1.00%
# 8            1.28%
# 9            2.32%
# 10           1.32%
# 11           6.22%
# 12           5.90%
# 13           3.71%
# 14           2.69%
# 15           0.91%
# 16           3.60%
# 17           2.45%
# 18           4.89%
# 19           1.65%
# 20           5.43%
# 21           2.48%
# 22           3.15%
# 23           3.38%
# 24           3.38%
# 25          10.14%
# 26           0.97%
# 27           4.06%
# 28           0.88%
# 29           3.04%

# %%
# scrape wiki table with symbols and details of s&P500 constituents
sp_constituents = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]#.to_csv('constintuents_current.csv', index=False)
sp_constituents.rename(columns={'Symbol': 'ticker', 'Security':'name', 'Headquarters Location': 'hq_location',
                                'GICS Sector': 'sector', 'GICS Sub-Industry':'industry'},inplace=True)
sp_constituents.head()
# Out:
#   ticker         name SEC filings       sector                  industry  \
# 0    MMM           3M     reports  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith     reports  Industrials         Building Products
# 2    ABT       Abbott     reports  Health Care     Health Care Equipment
# 3   ABBV       AbbVie     reports  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed     reports  Health Care     Health Care Equipment
#
#                hq_location Date first added      CIK      Founded
# 0    Saint Paul, Minnesota       1976-08-09    66740         1902
# 1     Milwaukee, Wisconsin       2017-07-26    91142         1916
# 2  North Chicago, Illinois       1964-03-31     1800         1888
# 3  North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 4   Danvers, Massachusetts       2018-05-31   815094         1981

# %%
#YOUR CODE
#concetenate the previous tables/dataframe sp_constituents & dj_constituents with  the columns'name', 'industry', 'sector', 'hq_location'
company_table = pd.concat([sp_constituents, dj_constituents])
company_table = company_table[['name', 'industry', 'sector', 'hq_location']]

#drop duplicate
company_table.drop_duplicates(subset=['name'], inplace= True)

#sort
company_table.sort_values(by=['name'], inplace=True)

#reset index
company_table.reset_index(drop=True,inplace=True)

#create the colum id based on the index
company_table['id']= company_table.index
company_table
# Out:
#                      name                                      industry  \
# 0                      3M                      Industrial Conglomerates
# 1             A. O. Smith                             Building Products
# 2                     ADM                         Agricultural Products
# 3                     ADP         Data Processing & Outsourced Services
# 4         AES Corporation  Independent Power Producers & Energy Traders
# ..                    ...                                           ...
# 509    Zebra Technologies            Electronic Equipment & Instruments
# 510         Zimmer Biomet                         Health Care Equipment
# 511  Zions Bancorporation                                Regional Banks
# 512                Zoetis                               Pharmaceuticals
# 513                  eBay            Internet & Direct Marketing Retail
#
#                      sector             hq_location   id
# 0               Industrials   Saint Paul, Minnesota    0
# 1               Industrials    Milwaukee, Wisconsin    1
# 2          Consumer Staples       Chicago, Illinois    2
# 3    Information Technology    Roseland, New Jersey    3
# 4                 Utilities     Arlington, Virginia    4
# ..                      ...                     ...  ...
# 509  Information Technology  Lincolnshire, Illinois  509
# 510             Health Care         Warsaw, Indiana  510
# 511              Financials    Salt Lake City, Utah  511
# 512             Health Care  Parsippany, New Jersey  512
# 513  Consumer Discretionary    San Jose, California  513
#
# [514 rows x 5 columns]

# %%
company_table
# Out:
#                      name                                      industry  \
# 0                      3M                      Industrial Conglomerates
# 1             A. O. Smith                             Building Products
# 2                     ADM                         Agricultural Products
# 3                     ADP         Data Processing & Outsourced Services
# 4         AES Corporation  Independent Power Producers & Energy Traders
# ..                    ...                                           ...
# 509    Zebra Technologies            Electronic Equipment & Instruments
# 510         Zimmer Biomet                         Health Care Equipment
# 511  Zions Bancorporation                                Regional Banks
# 512                Zoetis                               Pharmaceuticals
# 513                  eBay            Internet & Direct Marketing Retail
#
#                      sector             hq_location   id
# 0               Industrials   Saint Paul, Minnesota    0
# 1               Industrials    Milwaukee, Wisconsin    1
# 2          Consumer Staples       Chicago, Illinois    2
# 3    Information Technology    Roseland, New Jersey    3
# 4                 Utilities     Arlington, Virginia    4
# ..                      ...                     ...  ...
# 509  Information Technology  Lincolnshire, Illinois  509
# 510             Health Care         Warsaw, Indiana  510
# 511              Financials    Salt Lake City, Utah  511
# 512             Health Care  Parsippany, New Jersey  512
# 513  Consumer Discretionary    San Jose, California  513
#
# [514 rows x 5 columns]

# %%
#concetenate the previous tables/dataframe sp_constituents & dj_constituents with  the columns'ticker', 'name'
#drop duplicate
#sort
#reset index
#create the colum id based on the index

#YOUR CODE 
sp_security_table= sp_constituents[['ticker', 'name']]
dj_security_table= dj_constituents[['ticker', 'name']]

security_table = pd.concat([sp_security_table, dj_security_table])
#security_table = security_table[['ticker', 'name']]

#drop duplicate
security_table.drop_duplicates(subset=['ticker'], inplace= True)

#sort
security_table.sort_values(by=['ticker'],inplace=True)

#reset index
security_table.reset_index(drop=True,inplace=True)

#create the colum id based on the index
security_table['id']= security_table.index
security_table
# Out:
#     ticker                     name   id
# 0        A     Agilent Technologies    0
# 1      AAL  American Airlines Group    1
# 2      AAP       Advance Auto Parts    2
# 3     AAPL               Apple Inc.    3
# 4     ABBV                   AbbVie    4
# ..     ...                      ...  ...
# 498    YUM              Yum! Brands  498
# 499    ZBH            Zimmer Biomet  499
# 500   ZBRA       Zebra Technologies  500
# 501   ZION     Zions Bancorporation  501
# 502    ZTS                   Zoetis  502
#
# [503 rows x 3 columns]

# %%
security_table
# Out:
#     ticker                     name   id
# 0        A     Agilent Technologies    0
# 1      AAL  American Airlines Group    1
# 2      AAP       Advance Auto Parts    2
# 3     AAPL               Apple Inc.    3
# 4     ABBV                   AbbVie    4
# ..     ...                      ...  ...
# 498    YUM              Yum! Brands  498
# 499    ZBH            Zimmer Biomet  499
# 500   ZBRA       Zebra Technologies  500
# 501   ZION     Zions Bancorporation  501
# 502    ZTS                   Zoetis  502
#
# [503 rows x 3 columns]

# %%
#create the foreign key :  populating the security table with the company_id
#first step : create a dictionary with key, value pairs being the name of the company and the corresponding id 
#within its own table, which will be our foreign key in the second table.

# %%
#YOUT CODE 

keys = company_table['name']
values = company_table['id']
company_id_mapper = dict(zip(keys, values))
display(company_id_mapper)
# Out:
# {'3M': 0,
#  'A. O. Smith': 1,
#  'ADM': 2,
#  'ADP': 3,
#  'AES Corporation': 4,
#  'AMD': 5,
#  'APA Corporation': 6,
#  'AT&T': 7,
#  'AbbVie': 8,
#  'Abbott': 9,
#  'Abiomed': 10,
#  'Accenture': 11,
#  'Activision Blizzard': 12,
#  'Adobe Inc.': 13,
#  'Advance Auto Parts': 14,
#  'Aflac': 15,
#  'Agilent Technologies': 16,
#  'Air Products and Chemicals': 17,
#  'Akamai': 18,
#  'Alaska Air Group': 19,
#  'Albemarle Corporation': 20,
#  'Alexandria Real Estate Equities': 21,
#  'Align Technology': 22,
#  'Allegion': 23,
#  'Alliant Energy': 24,
#  'Allstate': 25,
#  'Alphabet Inc. (Class A)': 26,
#  'Alphabet Inc. (Class C)': 27,
#  'Altria': 28,
#  'Amazon': 29,
#  'Amcor': 30,
#  'Ameren': 31,
#  'American Airlines Group': 32,
#  'American Electric Power': 33,
#  'American Express': 34,
#  'American International Group': 35,
#  'American Tower': 36,
#  'American Water Works': 37,
#  'Ameriprise Financial': 38,
#  'AmerisourceBergen': 39,
#  'Ametek': 40,
#  'Amgen': 41,
#  'Amphenol': 42,
#  'Analog Devices': 43,
#  'Ansys': 44,
#  'Aon': 45,
#  'Apple': 46,
#  'Apple Inc.': 47,
#  'Applied Materials': 48,
#  'Aptiv': 49,
#  'Arch Capital Group': 50,
#  'Arista Networks': 51,
#  'Arthur J. Gallagher & Co.': 52,
#  'Assurant': 53,
#  'Atmos Energy': 54,
#  'AutoZone': 55,
#  'Autodesk': 56,
#  'AvalonBay Communities': 57,
#  'Avery Dennison': 58,
#  'BNY Mellon': 59,
#  'Baker Hughes': 60,
#  'Ball Corporation': 61,
#  'Bank of America': 62,
#  'Bath & Body Works, Inc.': 63,
#  'Baxter International': 64,
#  'Becton Dickinson': 65,
#  'Berkley': 66,
#  'Berkshire Hathaway': 67,
#  'Best Buy': 68,
#  'Bio-Rad': 69,
#  'Bio-Techne': 70,
#  'Biogen': 71,
#  'BlackRock': 72,
#  'Boeing': 73,
#  'Booking Holdings': 74,
#  'BorgWarner': 75,
#  'Boston Properties': 76,
#  'Boston Scientific': 77,
#  'Bristol Myers Squibb': 78,
#  'Broadcom Inc.': 79,
#  'Broadridge Financial Solutions': 80,
#  'Brown & Brown': 81,
#  'Brown–Forman': 82,
#  'C.H. Robinson': 83,
#  'CBRE Group': 84,
#  'CDW': 85,
#  'CF Industries': 86,
#  'CME Group': 87,
#  'CMS Energy': 88,
#  'CSX': 89,
#  'CVS Health': 90,
#  'Cadence Design Systems': 91,
#  'Caesars Entertainment': 92,
#  'Camden Property Trust': 93,
#  'Campbell Soup Company': 94,
#  'Capital One': 95,
#  'CarMax': 96,
#  'Cardinal Health': 97,
#  'Carnival': 98,
#  'Carrier Global': 99,
#  'Catalent': 100,
#  'Caterpillar': 101,
#  'Caterpillar Inc.': 102,
#  'Cboe Global Markets': 103,
#  'Celanese': 104,
#  'Centene Corporation': 105,
#  'CenterPoint Energy': 106,
#  'Ceridian': 107,
#  'Charles River Laboratories': 108,
#  'Charles Schwab Corporation': 109,
#  'Charter Communications': 110,
#  'Chevron': 111,
#  'Chevron Corporation': 112,
#  'Chipotle Mexican Grill': 113,
#  'Chubb Limited': 114,
#  'Church & Dwight': 115,
#  'Cigna': 116,
#  'Cincinnati Financial': 117,
#  'Cintas': 118,
#  'Cisco': 119,
#  'Citigroup': 120,
#  'Citizens Financial Group': 121,
#  'Clorox': 122,
#  'CoStar Group': 123,
#  'Coca-Cola': 124,
#  'Cognizant': 125,
#  'Colgate-Palmolive': 126,
#  'Comcast': 127,
#  'Comerica': 128,
#  'Conagra Brands': 129,
#  'ConocoPhillips': 130,
#  'Consolidated Edison': 131,
#  'Constellation Brands': 132,
#  'Constellation Energy': 133,
#  'CooperCompanies': 134,
#  'Copart': 135,
#  'Corning Inc.': 136,
#  'Corteva': 137,
#  'Costco': 138,
#  'Coterra': 139,
#  'Crown Castle': 140,
#  'Cummins': 141,
#  'D.R. Horton': 142,
#  'DTE Energy': 143,
#  'DXC Technology': 144,
#  'DaVita Inc.': 145,
#  'Danaher Corporation': 146,
#  'Darden Restaurants': 147,
#  'Delta Air Lines': 148,
#  'Dentsply Sirona': 149,
#  'Devon Energy': 150,
#  'Dexcom': 151,
#  'Diamondback Energy': 152,
#  'Digital Realty': 153,
#  'Discover Financial': 154,
#  'Dish Network': 155,
#  'Disney': 156,
#  'Dollar General': 157,
#  'Dollar Tree': 158,
#  'Dominion Energy': 159,
#  "Domino's": 160,
#  'Dover Corporation': 161,
#  'Dow': 162,
#  'Dow Inc.': 163,
#  'DuPont': 164,
#  'Duke Energy': 165,
#  'EOG Resources': 166,
#  'EPAM Systems': 167,
#  'EQT': 168,
#  'Eastman Chemical Company': 169,
#  'Eaton Corporation': 170,
#  'Ecolab': 171,
#  'Edison International': 172,
#  'Edwards Lifesciences': 173,
#  'Electronic Arts': 174,
#  'Elevance Health': 175,
#  'Eli Lilly and Company': 176,
#  'Emerson Electric': 177,
#  'Enphase': 178,
#  'Entergy': 179,
#  'Equifax': 180,
#  'Equinix': 181,
#  'Equity Residential': 182,
#  'Essex Property Trust': 183,
#  'Etsy': 184,
#  'Everest Re': 185,
#  'Evergy': 186,
#  'Eversource': 187,
#  'Exelon': 188,
#  'Expedia Group': 189,
#  'Expeditors International': 190,
#  'Extra Space Storage': 191,
#  'ExxonMobil': 192,
#  'F5, Inc.': 193,
#  'FIS': 194,
#  'FMC Corporation': 195,
#  'FactSet': 196,
#  'Fastenal': 197,
#  'FedEx': 198,
#  'Federal Realty': 199,
#  'Fifth Third Bank': 200,
#  'First Republic Bank': 201,
#  'FirstEnergy': 202,
#  'Fiserv': 203,
#  'Fleetcor': 204,
#  'Ford Motor Company': 205,
#  'Fortinet': 206,
#  'Fortive': 207,
#  'Fortune Brands Home & Security': 208,
#  'Fox Corporation (Class A)': 209,
#  'Fox Corporation (Class B)': 210,
#  'Franklin Templeton': 211,
#  'Freeport-McMoRan': 212,
#  'Garmin': 213,
#  'Gartner': 214,
#  'Gen Digital Inc.': 215,
#  'Generac': 216,
#  'General Dynamics': 217,
#  'General Electric': 218,
#  'General Mills': 219,
#  'General Motors': 220,
#  'Genuine Parts Company': 221,
#  'Gilead Sciences': 222,
#  'Global Payments': 223,
#  'Globe Life': 224,
#  'Goldman Sachs': 225,
#  'HCA Healthcare': 226,
#  'HP Inc.': 227,
#  'Halliburton': 228,
#  'Hartford (The)': 229,
#  'Hasbro': 230,
#  'Healthpeak': 231,
#  'Henry Schein': 232,
#  "Hershey's": 233,
#  'Hess Corporation': 234,
#  'Hewlett Packard Enterprise': 235,
#  'Hilton Worldwide': 236,
#  'Hologic': 237,
#  'Home Depot': 238,
#  'Honeywell': 239,
#  'Hormel Foods': 240,
#  'Host Hotels & Resorts': 241,
#  'Howmet Aerospace': 242,
#  'Humana': 243,
#  'Huntington Bancshares': 244,
#  'Huntington Ingalls Industries': 245,
#  'IBM': 246,
#  'IDEX Corporation': 247,
#  'IQVIA': 248,
#  'Idexx Laboratories': 249,
#  'Illinois Tool Works': 250,
#  'Illumina': 251,
#  'Incyte': 252,
#  'Ingersoll Rand': 253,
#  'Intel': 254,
#  'Intercontinental Exchange': 255,
#  'International Flavors & Fragrances': 256,
#  'International Paper': 257,
#  'Intuit': 258,
#  'Intuitive Surgical': 259,
#  'Invesco': 260,
#  'Invitation Homes': 261,
#  'Iron Mountain': 262,
#  'J.B. Hunt': 263,
#  'JPMorgan Chase': 264,
#  'Jack Henry & Associates': 265,
#  'Jacobs Solutions': 266,
#  'John Deere': 267,
#  'Johnson & Johnson': 268,
#  'Johnson Controls': 269,
#  'Juniper Networks': 270,
#  'KLA Corporation': 271,
#  "Kellogg's": 272,
#  'Keurig Dr Pepper': 273,
#  'KeyCorp': 274,
#  'Keysight': 275,
#  'Kimberly-Clark': 276,
#  'Kimco Realty': 277,
#  'Kinder Morgan': 278,
#  'Kraft Heinz': 279,
#  'Kroger': 280,
#  'L3Harris': 281,
#  'LKQ Corporation': 282,
#  'LabCorp': 283,
#  'Lam Research': 284,
#  'Lamb Weston': 285,
#  'Las Vegas Sands': 286,
#  'Leidos': 287,
#  'Lennar': 288,
#  'Lincoln Financial': 289,
#  'Linde plc': 290,
#  'Live Nation Entertainment': 291,
#  'Lockheed Martin': 292,
#  'Loews Corporation': 293,
#  "Lowe's": 294,
#  'Lumen Technologies': 295,
#  'LyondellBasell': 296,
#  'M&T Bank': 297,
#  'MGM Resorts': 298,
#  'MSCI': 299,
#  'Marathon Oil': 300,
#  'Marathon Petroleum': 301,
#  'MarketAxess': 302,
#  'Marriott International': 303,
#  'Marsh McLennan': 304,
#  'Martin Marietta Materials': 305,
#  'Masco': 306,
#  'Mastercard': 307,
#  'Match Group': 308,
#  'McCormick & Company': 309,
#  "McDonald's": 310,
#  'McKesson': 311,
#  'Medtronic': 312,
#  'Merck': 313,
#  'Merck & Co.': 314,
#  'MetLife': 315,
#  'Meta Platforms': 316,
#  'Mettler Toledo': 317,
#  'Microchip Technology': 318,
#  'Micron Technology': 319,
#  'Microsoft': 320,
#  'Mid-America Apartment Communities': 321,
#  'Moderna': 322,
#  'Mohawk Industries': 323,
#  'Molina Healthcare': 324,
#  'Molson Coors Beverage Company': 325,
#  'Mondelez International': 326,
#  'Monolithic Power Systems': 327,
#  'Monster Beverage': 328,
#  "Moody's Corporation": 329,
#  'Morgan Stanley': 330,
#  'Motorola Solutions': 331,
#  'NRG Energy': 332,
#  'NVR, Inc.': 333,
#  'NXP Semiconductors': 334,
#  'Nasdaq, Inc.': 335,
#  'NetApp': 336,
#  'Netflix': 337,
#  'Newell Brands': 338,
#  'Newmont': 339,
#  'News Corp (Class A)': 340,
#  'News Corp (Class B)': 341,
#  'NextEra Energy': 342,
#  'NiSource': 343,
#  'Nike': 344,
#  'Nike, Inc.': 345,
#  'Nordson Corporation': 346,
#  'Norfolk Southern Railway': 347,
#  'Northern Trust': 348,
#  'Northrop Grumman': 349,
#  'Norwegian Cruise Line Holdings': 350,
#  'Nucor': 351,
#  'Nvidia': 352,
#  "O'Reilly Auto Parts": 353,
#  'ON Semiconductor': 354,
#  'Occidental Petroleum': 355,
#  'Old Dominion': 356,
#  'Omnicom Group': 357,
#  'Oneok': 358,
#  'Oracle Corporation': 359,
#  'Organon & Co.': 360,
#  'Otis Worldwide': 361,
#  'PG&E': 362,
#  'PNC Financial Services': 363,
#  'PPG Industries': 364,
#  'PPL Corporation': 365,
#  'PTC': 366,
#  'Paccar': 367,
#  'Packaging Corporation of America': 368,
#  'Paramount Global': 369,
#  'Parker Hannifin': 370,
#  'PayPal': 371,
#  'Paychex': 372,
#  'Paycom': 373,
#  'Pentair': 374,
#  'PepsiCo': 375,
#  'PerkinElmer': 376,
#  'Pfizer': 377,
#  'Philip Morris International': 378,
#  'Phillips 66': 379,
#  'Pinnacle West': 380,
#  'Pioneer Natural Resources': 381,
#  'Pool Corporation': 382,
#  'Principal Financial Group': 383,
#  'Procter & Gamble': 384,
#  'Progressive Corporation': 385,
#  'Prologis': 386,
#  'Prudential Financial': 387,
#  'Public Service Enterprise Group': 388,
#  'Public Storage': 389,
#  'PulteGroup': 390,
#  'Qorvo': 391,
#  'Qualcomm': 392,
#  'Quanta Services': 393,
#  'Quest Diagnostics': 394,
#  'Ralph Lauren Corporation': 395,
#  'Raymond James': 396,
#  'Raytheon Technologies': 397,
#  'Realty Income': 398,
#  'Regency Centers': 399,
#  'Regeneron': 400,
#  'Regions Financial Corporation': 401,
#  'Republic Services': 402,
#  'ResMed': 403,
#  'Robert Half': 404,
#  'Rockwell Automation': 405,
#  'Rollins, Inc.': 406,
#  'Roper Technologies': 407,
#  'Ross Stores': 408,
#  'Royal Caribbean Group': 409,
#  'S&P Global': 410,
#  'SBA Communications': 411,
#  'SVB Financial': 412,
#  'Salesforce': 413,
#  'Schlumberger': 414,
#  'Seagate Technology': 415,
#  'Sealed Air': 416,
#  'Sempra Energy': 417,
#  'ServiceNow': 418,
#  'Sherwin-Williams': 419,
#  'Signature Bank': 420,
#  'Simon Property Group': 421,
#  'Skyworks Solutions': 422,
#  'Snap-on': 423,
#  'SolarEdge': 424,
#  'Southern Company': 425,
#  'Southwest Airlines': 426,
#  'Stanley Black & Decker': 427,
#  'Starbucks': 428,
#  'State Street Corporation': 429,
#  'Steris': 430,
#  'Stryker Corporation': 431,
#  'Synchrony Financial': 432,
#  'Synopsys': 433,
#  'Sysco': 434,
#  'T-Mobile US': 435,
#  'T. Rowe Price': 436,
#  'TE Connectivity': 437,
#  'TJX Companies': 438,
#  'Take-Two Interactive': 439,
#  'Tapestry, Inc.': 440,
#  'Targa Resources': 441,
#  'Target Corporation': 442,
#  'Teledyne Technologies': 443,
#  'Teleflex': 444,
#  'Teradyne': 445,
#  'Tesla, Inc.': 446,
#  'Texas Instruments': 447,
#  'Textron': 448,
#  'The Coca-Cola Company': 449,
#  'The Estée Lauder Companies': 450,
#  'The Home Depot': 451,
#  'The Interpublic Group of Companies': 452,
#  'The J.M. Smucker Company': 453,
#  'The Mosaic Company': 454,
#  'The Travelers Companies': 455,
#  'Thermo Fisher Scientific': 456,
#  'Tractor Supply': 457,
#  'Trane Technologies': 458,
#  'TransDigm Group': 459,
#  'Travelers': 460,
#  'Trimble Inc.': 461,
#  'Truist': 462,
#  'Tyler Technologies': 463,
#  'Tyson Foods': 464,
#  'U.S. Bank': 465,
#  'UDR, Inc.': 466,
#  'Ulta Beauty': 467,
#  'Union Pacific Corporation': 468,
#  'United Airlines Holdings': 469,
#  'United Parcel Service': 470,
#  'United Rentals': 471,
#  'UnitedHealth': 472,
#  'UnitedHealth Group': 473,
#  'Universal Health Services': 474,
#  'VF Corporation': 475,
#  'Valero Energy': 476,
#  'Ventas': 477,
#  'Verisign': 478,
#  'Verisk': 479,
#  'Verizon': 480,
#  'Vertex Pharmaceuticals': 481,
#  'Viatris': 482,
#  'Vici Properties': 483,
#  'Visa': 484,
#  'Visa Inc.': 485,
#  'Vornado Realty Trust': 486,
#  'Vulcan Materials Company': 487,
#  'W. W. Grainger': 488,
#  'WEC Energy Group': 489,
#  'Wabtec': 490,
#  'Walgreens Boots Alliance': 491,
#  'Walmart': 492,
#  'Warner Bros. Discovery': 493,
#  'Waste Management': 494,
#  'Waters Corporation': 495,
#  'Wells Fargo': 496,
#  'Welltower': 497,
#  'West Pharmaceutical Services': 498,
#  'WestRock': 499,
#  'Western Digital': 500,
#  'Weyerhaeuser': 501,
#  'Whirlpool Corporation': 502,
#  'Williams Companies': 503,
#  'Willis Towers Watson': 504,
#  'Wynn Resorts': 505,
#  'Xcel Energy': 506,
#  'Xylem Inc.': 507,
#  'Yum! Brands': 508,
#  'Zebra Technologies': 509,
#  'Zimmer Biomet': 510,
#  'Zions Bancorporation': 511,
#  'Zoetis': 512,
#  'eBay': 513}

# %%
#Seconde step: create the foreign key company id 
#YOUR CODE 
security_table['company_id'] = security_table['name'] .map(company_id_mapper)
security_table.head(30)
# Out:
#    ticker                          name  id  company_id
# 0       A          Agilent Technologies   0          16
# 1     AAL       American Airlines Group   1          32
# 2     AAP            Advance Auto Parts   2          14
# 3    AAPL                    Apple Inc.   3          47
# 4    ABBV                        AbbVie   4           8
# 5     ABC             AmerisourceBergen   5          39
# 6    ABMD                       Abiomed   6          10
# 7     ABT                        Abbott   7           9
# 8    ACGL            Arch Capital Group   8          50
# 9     ACN                     Accenture   9          11
# 10   ADBE                    Adobe Inc.  10          13
# 11    ADI                Analog Devices  11          43
# 12    ADM                           ADM  12           2
# 13    ADP                           ADP  13           3
# 14   ADSK                      Autodesk  14          56
# 15    AEE                        Ameren  15          31
# 16    AEP       American Electric Power  16          33
# 17    AES               AES Corporation  17           4
# 18    AFL                         Aflac  18          15
# 19    AIG  American International Group  19          35
# 20    AIZ                      Assurant  20          53
# 21    AJG     Arthur J. Gallagher & Co.  21          52
# 22   AKAM                        Akamai  22          18
# 23    ALB         Albemarle Corporation  23          20
# 24   ALGN              Align Technology  24          22
# 25    ALK              Alaska Air Group  25          19
# 26    ALL                      Allstate  26          25
# 27   ALLE                      Allegion  27          23
# 28   AMAT             Applied Materials  28          48
# 29   AMCR                         Amcor  29          30

# %%
security_table
# Out:
#     ticker                     name   id  company_id
# 0        A     Agilent Technologies    0          16
# 1      AAL  American Airlines Group    1          32
# 2      AAP       Advance Auto Parts    2          14
# 3     AAPL               Apple Inc.    3          47
# 4     ABBV                   AbbVie    4           8
# ..     ...                      ...  ...         ...
# 498    YUM              Yum! Brands  498         508
# 499    ZBH            Zimmer Biomet  499         510
# 500   ZBRA       Zebra Technologies  500         509
# 501   ZION     Zions Bancorporation  501         511
# 502    ZTS                   Zoetis  502         512
#
# [503 rows x 4 columns]

# %%
#create the foreign key : populate the company table with the security_id:
#YOUR CODE 

security_id_mapper = dict(zip(security_table['name'], security_table['id']))
company_table['security_id'] = company_table['name'] .map(security_id_mapper)
company_table.head(30)
# Out:
#                                name  \
# 0                                3M
# 1                       A. O. Smith
# 2                               ADM
# 3                               ADP
# 4                   AES Corporation
# 5                               AMD
# 6                   APA Corporation
# 7                              AT&T
# 8                            AbbVie
# 9                            Abbott
# 10                          Abiomed
# 11                        Accenture
# 12              Activision Blizzard
# 13                       Adobe Inc.
# 14               Advance Auto Parts
# 15                            Aflac
# 16             Agilent Technologies
# 17       Air Products and Chemicals
# 18                           Akamai
# 19                 Alaska Air Group
# 20            Albemarle Corporation
# 21  Alexandria Real Estate Equities
# 22                 Align Technology
# 23                         Allegion
# 24                   Alliant Energy
# 25                         Allstate
# 26          Alphabet Inc. (Class A)
# 27          Alphabet Inc. (Class C)
# 28                           Altria
# 29                           Amazon
#
#                                         industry                  sector  \
# 0                       Industrial Conglomerates             Industrials
# 1                              Building Products             Industrials
# 2                          Agricultural Products        Consumer Staples
# 3          Data Processing & Outsourced Services  Information Technology
# 4   Independent Power Producers & Energy Traders               Utilities
# 5                                 Semiconductors  Information Technology
# 6             Oil & Gas Exploration & Production                  Energy
# 7          Integrated Telecommunication Services  Communication Services
# 8                                Pharmaceuticals             Health Care
# 9                          Health Care Equipment             Health Care
# 10                         Health Care Equipment             Health Care
# 11                IT Consulting & Other Services  Information Technology
# 12                Interactive Home Entertainment  Communication Services
# 13                          Application Software  Information Technology
# 14                             Automotive Retail  Consumer Discretionary
# 15                       Life & Health Insurance              Financials
# 16                         Health Care Equipment             Health Care
# 17                              Industrial Gases               Materials
# 18            Internet Services & Infrastructure  Information Technology
# 19                                      Airlines             Industrials
# 20                           Specialty Chemicals               Materials
# 21                                  Office REITs             Real Estate
# 22                          Health Care Supplies             Health Care
# 23                             Building Products             Industrials
# 24                            Electric Utilities               Utilities
# 25                 Property & Casualty Insurance              Financials
# 26                  Interactive Media & Services  Communication Services
# 27                  Interactive Media & Services  Communication Services
# 28                                       Tobacco        Consumer Staples
# 29            Internet & Direct Marketing Retail  Consumer Discretionary
#
#                       hq_location  id  security_id
# 0           Saint Paul, Minnesota   0        307.0
# 1            Milwaukee, Wisconsin   1         39.0
# 2               Chicago, Illinois   2         12.0
# 3            Roseland, New Jersey   3         13.0
# 4             Arlington, Virginia   4         17.0
# 5         Santa Clara, California   5         30.0
# 6                  Houston, Texas   6         40.0
# 7                   Dallas, Texas   7        429.0
# 8         North Chicago, Illinois   8          4.0
# 9         North Chicago, Illinois   9          7.0
# 10         Danvers, Massachusetts  10          6.0
# 11                Dublin, Ireland  11          9.0
# 12       Santa Monica, California  12         46.0
# 13           San Jose, California  13         10.0
# 14        Raleigh, North Carolina  14          2.0
# 15              Columbus, Georgia  15         18.0
# 16        Santa Clara, California  16          0.0
# 17        Allentown, Pennsylvania  17         41.0
# 18       Cambridge, Massachusetts  18         22.0
# 19             SeaTac, Washington  19         25.0
# 20      Charlotte, North Carolina  20         23.0
# 21           Pasadena, California  21         44.0
# 22                 Tempe, Arizona  22         24.0
# 23        New York City, New York  23         27.0
# 24             Madison, Wisconsin  24        280.0
# 25  Northfield Township, Illinois  25         26.0
# 26      Mountain View, California  26        207.0
# 27      Mountain View, California  27        206.0
# 28             Richmond, Virginia  28        309.0
# 29            Seattle, Washington  29         35.0

# %%
#Reda the nyse.csv and the nasdaq.csv
#YOUR CODE 
nyse = pd.read_csv('nyse.csv')
nasdaq = pd.read_csv('nasdaq.csv')

nyse.head()
# Out:
#   Symbol                    Name  LastSale MarketCap  IPOyear  \
# 0    DDD  3D Systems Corporation      7.66  $927.89M      NaN
# 1    MMM              3M Company    169.80   $97.81B      NaN
# 2   WBAI         500.com Limited      2.95  $126.85M   2013.0
# 3   EGHT                 8x8 Inc     16.75    $1.75B      NaN
# 4    AHC   A.H. Belo Corporation      1.44   $34.39M      NaN
#
#               Sector                                 industry  \
# 0         Technology  Computer Software: Prepackaged Software
# 1        Health Care               Medical/Dental Instruments
# 2  Consumer Services    Services-Misc. Amusement & Recreation
# 3         Technology                             EDP Services
# 4  Consumer Services                     Newspapers/Magazines
#
#                         Summary Quote  Unnamed: 8
# 0   https://old.nasdaq.com/symbol/ddd         NaN
# 1   https://old.nasdaq.com/symbol/mmm         NaN
# 2  https://old.nasdaq.com/symbol/wbai         NaN
# 3  https://old.nasdaq.com/symbol/eght         NaN
# 4   https://old.nasdaq.com/symbol/ahc         NaN

# %%
nasdaq.head()
# Out:
#   Symbol                                    Name  LastSale     MarketCap  \
# 0   VCVC    10X Capital Venture Acquisition Corp       NaN  0.000000e+00
# 1  VCVCU    10X Capital Venture Acquisition Corp       NaN  0.000000e+00
# 2    TXG                      10x Genomics, Inc.    142.27  1.520301e+10
# 3     YI                               111, Inc.      7.00  1.785821e+08
# 4    PIH  1347 Property Insurance Holdings, Inc.      3.05  1.506076e+07
#
#       ADR TSO  IPOyear         Sector  \
# 0         NaN      NaN            NaN
# 1         NaN      NaN            NaN
# 2         NaN   2019.0  Capital Goods
# 3  25511734.0   2018.0    Health Care
# 4         NaN   2014.0        Finance
#
#                                            Industry  \
# 0                                               NaN
# 1                                               NaN
# 2  Biotechnology: Laboratory Analytical Instruments
# 3                          Medical/Nursing Services
# 4                        Property-Casualty Insurers
#
#                          Summary Quote  Unnamed: 9
# 0   https://old.nasdaq.com/symbol/vcvc         NaN
# 1  https://old.nasdaq.com/symbol/vcvcu         NaN
# 2    https://old.nasdaq.com/symbol/txg         NaN
# 3     https://old.nasdaq.com/symbol/yi         NaN
# 4    https://old.nasdaq.com/symbol/pih         NaN

# %%
#populate the exchange_id column : assign the correct exchange_id for each stock in the security table:
# the exchange_id of the nyse stocks will be 1300
#YOUR CODE
security_table

# %%
#populate the exchange_id column : assign the correct exchange_id for each stock in the security table:
# the exchange_id of  will be 1300 for the nyse stocks and 367 for the nasdaq stocks
#YOUR CODE

#YOUR CODE 
security_table.head(30)

# %%
#save the data in the sql table security and company of the database db_name
#YOUR CODE

# %%
#Extraction the prices of YAHOO: WARNING this action may take 15 min !!!
from tqdm import tqdm_notebook as tqdm
import pandas_datareader.data as web
stock_pricing_dfs = []
for stock_id in tqdm(security_table['id']):
    try:
        stock_pricing_df = web.DataReader(security_table.iloc[stock_id]['ticker'], 
                           start='2010-1-1', 
                           end='2020-08-31', 
                           data_source='yahoo')
        stock_pricing_df['security_id'] = stock_id
        stock_pricing_dfs.append(stock_pricing_df)
    except:
        pass
security_price_table = pd.concat(stock_pricing_dfs)

# %%
security_price_table.info()

# %%
#insert data in the table security_price
security_price_table.columns = ['high', 'low', 'open', 'close', 'volume', 'adj_close', 'security_id']
security_price_table.reset_index(inplace=True)
security_price_table['id'] = security_price_table.index
print(security_price_table.head())
security_price_table.to_sql("security_price", conn, if_exists="append", index=False)
